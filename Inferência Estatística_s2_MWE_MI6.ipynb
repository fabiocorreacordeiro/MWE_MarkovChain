# %% [markdown]
# ### Infêrência Estatística
# # Título: Avaliação do impacto da expressões multipalavras nos modelos de linguagem

# %% [markdown]
# Este script é similar ao caso base. Mas antes de criar o modelo de linguagem, identificamos as possíveis expressões multipalavras e substituímos a expressão por um único token.

# %%
import markovify
import os
import time
import json
import nltk
from nltk.probability import FreqDist
from nltk.tokenize import MWETokenizer
from nltk.tokenize.treebank import TreebankWordDetokenizer
import math
import numpy as np

# %% [markdown]
# Baseamos o código no Read me da biblioteca "Markovify" em: https://github.com/jsvine/markovify/blob/master/README.md

# %% [markdown]
# Primeiro criamos uma função para preprocessar o texto.

# %%
# Primeiro, criamos uma função para preprocessar os textos
def preprocess(text):
    # Decodificar usando ISO 8859-1 
    text = text.decode('ISO 8859-1')
    # Colocar todas as letras em minúscula
    text = text.lower()
    # Separar as sentenças pelos pontos de finais
    text = text.split('.')
    new_text = []
    for sent in text:
        # Eliminamos as sentenças com menos de 100 caracteres
        if len(sent)> 100:
            # Excluir os espaços no início e fim das sentenças
            new_text.append(sent.strip())
    return(new_text)

# %% [markdown]
# Unir os textos em um corpus único para identificar a frequência das palavras e dos bigrams

# %%
# Contador de tempo
start_time = time.time()

for (dirpath, _, filenames) in os.walk("Originais/treino"):
    for filename in filenames:
        # Dicionário para armazenar a frequência da palavras
        freq_words = {}
        freq_bigram = {}
        
        # Ler o arquivo e recuperar a frequência das palavras e dos bibrams
        with open(os.path.join(dirpath, filename), 'rb') as f:
            # Preprocessar o texto lido
            text = preprocess(f.read())
            # Iterando por cada sentença
            for sent in text:
                # tokenizando as sentenças
                sent = nltk.word_tokenize(sent)
                # Recuperando a frequência das palavras da sentença
                freq = FreqDist(sent)
                # Atualizando o dicionário com frequência das palavras
                for i in freq:
                    try:
                        freq_words[i] = freq_words[i] + freq[i]
                    except:
                        freq_words[i] = freq[i]
                # Recuperando os bigram
                bigram = nltk.bigrams(sent)
                for i in bigram:
                    try:
                        freq_bigram[i] = freq_bigram[i] + 1
                    except:
                        freq_bigram[i] = 1      
                        
# Fim do contador de tempo
print ("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 111.9474127292633 seconds ---

# %% [markdown]
# Com a informação das frequências das palavras e dos bigram, é possível calcular a informação mútua.

# %%
# Calculando a Informação Mútua para cada bigram
bigram_MI = {}
n_bigram = len(freq_bigram)
n_word = len(freq_words)
for bi in freq_bigram:
    bigram_MI[bi] = math.log((freq_bigram[bi]/n_bigram)/
                             ((freq_words[bi[0]]/n_bigram)*(freq_words[bi[1]]/n_bigram)))

# %%
# Imprimindo o número total de bigrams encontrado
print (len(bigram_MI))
# Out:
# 11418

# %% [markdown]
# Vamos considerar que um bigram é uma MWE aqueles pares de palavras cuja Informação Mútua ultrapassar um determinado limite.

# %%
# Criar uma lista de MWE com os bigrams que ultrapassem o limite assinalado na variável "MI".
mwe = {}
MI = 6.0
for bi in bigram_MI:
    if bigram_MI[bi] > MI:
        mwe[bi] = bigram_MI[bi]
print(len(mwe))
for e in mwe:
    print(bigram_MI[e], e[0], e[1])
# Out:
# 1302
# 6.164892506176259 químicos tóxicos
# 7.733508424090104 provocar riscos
# 7.733508424090104 saúde humana
# 6.164892506176259 uso residencial
# 6.047109470519875 áreas contaminadas
# 9.342946336524204 mancha urbana
# 7.040361243530159 contaminações provocam
# 6.858039686736205 provocam risco
# 9.342946336524204 anterior vocação
# 9.342946336524204 vocação industrial
# 7.145721759187985 setor residencial
# 8.244334047856094 residencial possam
# 9.342946336524204 possam cumprir
# 6.047109470519875 cumprir sua
# 6.251903883165888 função social
# 8.649799155964258 situações provocadas
# 8.649799155964258 geram conflitos
# 7.397036187468891 estado legislar
# 8.649799155964258 esses conflitos
# 8.649799155964258 conflitos ganharam
# 8.649799155964258 ganharam importância
# 6.164892506176259 importância durante
# 6.858039686736205 muitos países
# 7.956651975404314 estados unidos
# 9.342946336524204 américa iniciaram
# 9.342946336524204 audaciosos programas
# 9.342946336524204 ato comprehensive
# 8.649799155964258 comprehensive environmental
# 8.649799155964258 environmental response
# 8.649799155964258 and liability
# 7.263504794844368 lei federal
# 8.649799155964258 federal norte-americana
# 7.733508424090104 crédito conhecido
# 9.342946336524204 united states
# 8.649799155964258 states environmental
# 8.649799155964258 environmental protection
# 8.244334047856094 protection agency
# 6.047109470519875 desde sua
# 6.047109470519875 sua criação
# 7.328043315981939 novas tecnologias
# 8.244334047856094 tecnologias aplicáveis
# 6.347214062970213 25 anos
# 7.397036187468891 investidos 28
# 6.298423898800782 28 bilhões
# 8.244334047856094 indústrias químicas
# 8.649799155964258 agências governamentais
# 9.342946336524204 banco mundial
# 9.342946336524204 mundial formaram
# 8.649799155964258 global pollution
# 9.342946336524204 pollution remediation
# 9.342946336524204 remediation fund
# 7.551186867296149 remediar 400
# 6.45257457862804 contaminadas distribuídas
# 6.509732992467988 distribuídas pelo
# 7.551186867296149 estas remediações
# 9.342946336524204 remediações afetarão
# 9.342946336524204 afetarão positivamente
# 7.551186867296149 400 milhões
# 7.956651975404314 país considerado
# 9.342946336524204 políticas públicas
# 7.956651975404314 governo federal
# 9.342946336524204 casa civil
# 8.649799155964258 ministry of
# 8.649799155964258 of housing
# 7.397036187468891 desenvolvimento territorial
# 9.342946336524204 spatial planing
# 6.298423898800781 áreas degradadas
# 7.956651975404314 diversos níveis
# 8.649799155964258 níveis governamentais
# 8.244334047856094 setor privado
# 6.298423898800781 000 áreas
# 9.342946336524204 descontaminadas urgentemente
# 8.649799155964258 agência européia
# 6.298423898800782 alguns exemplos
# 7.956651975404314 quão importante
# 8.649799155964258 encontrar meios
# 8.649799155964258 principio básico
# 8.649799155964258 poluidor pagador
# 7.956651975404314 impossibilidade financeira
# 8.649799155964258 governo responsabiliza-se
# 8.649799155964258 fundos específicos
# 7.733508424090104 ter eclodido
# 9.342946336524204 resolução conama
# 9.342946336524204 conama 420/09
# 8.244334047856094 política nacional
# 9.342946336524204 atraso brasileiro
# 9.342946336524204 ferramentas institucionais
# 7.956651975404314 importância social
# 6.010741826349001 deve aumentar
# 9.342946336524204 atual expansão
# 8.244334047856094 setor imobiliário
# 8.244334047856094 imobiliário residencial
# 8.244334047856094 grandes cidades
# 7.040361243530159 esta demanda
# 6.634896135421995 atualmente existem
# 6.347214062970213 existem diversos
# 6.634896135421995 parte visando
# 7.040361243530159 processos envolvidos
# 6.251903883165888 contribuindo significativamente
# 7.551186867296149 conhecimento básico
# 6.084849798502723 básico sobre
# 7.956651975404314 necessário transformar
# 8.244334047856094 transformar esse
# 7.145721759187985 esse conhecimento
# 6.028760331851679 novas técnicas
# 7.956651975404314 investigação exaustiva
# 7.956651975404314 exaustiva vem
# 7.551186867296149 trabalho investiga
# 6.945051063725834 viabilidade técnica
# 6.634896135421995 remediação baseada
# 6.164892506176259 ensaios laboratoriais
# 9.342946336524204 soil flushing
# 9.342946336524204 esteja ele
# 6.164892506176259 zona vadosa
# 6.703889006908946 microorganismos acelerem
# 8.649799155964258 foco acelerar
# 6.110825284905983 solos contaminados
# 7.263504794844368 in situ
# 6.53958595561767 já adaptada
# 8.649799155964258 atividade microbiológica
# 8.649799155964258 períodos curtos
# 7.733508424090104 provavelmente insuficientes
# 6.298423898800782 visa investigar
# 7.145721759187985 microbiota adaptada
# 6.45257457862804 objetivo geral
# 6.858039686736205 pesquisa visa
# 6.22943102731383 visa avaliar
# 6.703889006908946 foco investigar
# 8.649799155964258 há sinergia
# 7.145721759187985 escala laboratorial
# 6.398507357357764 solos submetidos
# 6.010741826349001 '' identificar
# 7.263504794844368 identificar possíveis
# 7.956651975404314 possíveis correlações
# 7.263504794844368 outras formas
# 7.733508424090104 energia consumida
# 7.733508424090104 dados fornecidos
# 7.551186867296149 agência nacional
# 9.342946336524204 consumidos 108
# 6.164892506176259 média 96
# 6.945051063725834 categorias principais
# 7.956651975404314 concentra 75
# 7.040361243530159 energia elétrica
# 6.777996979062667 principal consumidor
# 7.551186867296149 ela leve
# 8.649799155964258 combustível encontra-se
# 8.244334047856094 amplamente espalhado
# 6.509732992467988 espalhado pelo
# 6.509732992467988 pelo território
# 8.244334047856094 território nacional
# 6.251903883165888 muito próximo
# 9.342946336524204 aglomerações humanas
# 7.397036187468891 solventes aromáticos
# 9.342946336524204 combustíveis líquidos
# 7.397036187468891 policíclicos aromáticos
# 6.858039686736205 últimos diretamente
# 6.45257457862804 diretamente relacionados
# 8.244334047856094 estatística numérica
# 7.551186867296149 seria fundamental
# 8.244334047856094 fundamental associar
# 9.342946336524204 associar algum
# 8.649799155964258 algum parâmetro
# 6.164892506176259 magnitude e/ou
# 7.145721759187985 determinar prioridades
# 6.703889006908946 outra constatação
# 7.263504794844368 constatação importante
# 6.347214062970213 importante consiste
# 7.145721759187985 tiveram medidas
# 6.634896135421995 remediação implementadas
# 6.1240705116560035 existem muitas
# 7.956651975404314 serem remediadas
# 6.45257457862804 contaminadas cadastradas
# 7.733508424090104 têm 382
# 6.298423898800781 382 áreas
# 6.298423898800781 áreas industriais
# 6.45257457862804 industriais contaminadas
# 6.45257457862804 contaminadas registradas
# 8.244334047856094 651 indústrias
# 6.398507357357764 possível concluir
# 7.551186867296149 avançado dentre
# 6.570357614284423 outras unidades
# 8.649799155964258 médio prazo
# 7.956651975404314 derramamento próximo
# 7.733508424090104 populações provavelmente
# 6.634896135421995 ainda ocorrerão
# 6.251903883165888 técnicas eficazes
# 6.634896135421995 remediação continuará
# 8.649799155964258 continuará contribuindo
# 7.733508424090104 saúde pública
# 8.649799155964258 caracterização físico-química
# 8.649799155964258 combustível derivado
# 8.244334047856094 constituído basicamente
# 7.145721759187985 38 átomos
# 7.397036187468891 características básicas
# 8.649799155964258 básicas descritas
# 6.347214062970213 petrobrás apresentam
# 7.551186867296149 produto inflamável
# 9.342946336524204 medianamente tóxico
# 8.244334047856094 odor forte
# 8.649799155964258 específico dependerá
# 6.298423898800781 também conter
# 7.956651975404314 conter vários
# 6.858039686736205 vários aditivos
# 6.010741826349001 composição final
# 6.047109470519875 melhorar sua
# 6.047109470519875 sua estabilidade
# 7.551186867296149 pesquisas leopoldo
# 9.342946336524204 leopoldo américo
# 9.342946336524204 américo miguez
# 7.040361243530159 interesse ambiental
# 6.298423898800782 todos aromáticos
# 8.244334047856094 fração molar
# 6.251903883165888 solubilidade efetiva
# 7.733508424090104 obtida experimentalmente
# 6.945051063725834 efetiva calculada
# 8.649799155964258 químicos caracterizados
# 8.244334047856094 international agency
# 8.244334047856094 agency research
# 9.342946336524204 research on
# 9.342946336524204 on cancer
# 8.244334047856094 perfis toxicológicos
# 7.145721759187985 agency for
# 8.244334047856094 for toxic
# 9.342946336524204 toxic substances
# 8.649799155964258 substances and
# 8.649799155964258 and disease
# 9.342946336524204 disease registry
# 6.703889006908946 vista ambiental
# 8.244334047856094 iarc classificou
# 7.733508424090104 comprovadamente carcinogênico
# 7.263504794844368 seres humanos
# 6.1240705116560035 provavelmente carcinogênico
# 6.347214062970213 possivelmente carcinogênico
# 6.164892506176259 compilação realizada
# 8.244334047856094 toxicológicos classifica
# 6.164892506176259 animais somente
# 6.8862105637029005 muitas vezes
# 7.397036187468891 vezes dependentes
# 9.342946336524204 relatos acidentais
# 6.945051063725834 significativa freqüência
# 8.244334047856094 subterrâneo motivou
# 6.010741826349001 três países
# 7.263504794844368 países considerados
# 9.342946336524204 neurologicos reprodutivos
# 7.397036187468891 reprodutivos desenvolvimento
# 8.244334047856094 feto dermico
# 8.244334047856094 dermico inalação
# 8.649799155964258 inalação oral
# 8.244334047856094 oral dermico
# 8.649799155964258 acenaftileno acenafteno
# 8.244334047856094 acenafteno fluoreno
# 7.145721759187985 antraceno fluoranteno
# 6.858039686736205 fluoranteno pireno
# 8.244334047856094 antraceno criseno
# 7.733508424090104 criseno benzo
# 7.328043315981939 fluoranteno benzo
# 7.956651975404314 pireno indeno
# 6.347214062970213 pireno benzo
# 7.263504794844368 dada população
# 7.956651975404314 população necessita-se
# 6.634896135421995 necessita-se avaliar
# 7.397036187468891 três aspectos
# 7.551186867296149 manuseio deste
# 8.244334047856094 bastante dispersa
# 7.040361243530159 menos densos
# 6.480745455594736 área contaminada
# 9.342946336524204 light non
# 9.342946336524204 non aquous
# 9.342946336524204 aquous phase
# 9.342946336524204 phase liquid
# 6.570357614284423 sub-superficial ocorre
# 8.649799155964258 migração vertical
# 8.244334047856094 líquido imiscível
# 6.1240705116560035 imiscível através
# 7.145721759187985 cujos poros
# 7.328043315981939 fica retida
# 8.649799155964258 lençol freático
# 7.551186867296149 freático subterrâneo
# 7.040361243530159 menos densa
# 7.733508424090104 pouco solúvel
# 7.733508424090104 pelas flutuações
# 8.649799155964258 freático ocasiona
# 6.570357614284423 formada tanto
# 6.251903883165888 lnapl interage
# 7.551186867296149 prioritariamente formada
# 6.010741826349001 e/ou vapor
# 6.347214062970213 superfície sólida
# 7.397036187468891 denominado sorção
# 6.1240705116560035 composto sorvido
# 6.45257457862804 ar entra
# 6.570357614284423 pode-se observar
# 7.263504794844368 fases citadas
# 7.551186867296149 segundo zaman
# 8.244334047856094 anteriormente descritos
# 8.244334047856094 descritos ocorrem
# 6.45257457862804 ocorrem naturalmente
# 7.551186867296149 alteração antrópica
# 7.956651975404314 será analisado
# 8.244334047856094 próximos capítulos
# 6.010741826349001 mobilidade natural
# 7.956651975404314 inicialmente investigada
# 7.145721759187985 poros estavam
# 9.342946336524204 estavam saturados
# 8.244334047856094 darcy formulou
# 6.858039686736205 poroso saturado
# 6.45257457862804 até hoje
# 6.347214062970213 hoje esta
# 8.649799155964258 meios porosos
# 6.9634002023940305 condutividade hidráulica
# 8.649799155964258 gradiente hidráulico
# 8.649799155964258 seção transversal
# 6.347214062970213 permeabilidade intrínseca
# 6.703889006908946 peso específico
# 7.263504794844368 viscosidade dinâmica
# 6.251903883165888 fluido posteriormente
# 8.244334047856094 desses conhecimentos
# 8.649799155964258 aquele previsto
# 7.551186867296149 isto porque
# 6.570357614284423 umidade volumétrico
# 7.040361243530159 permeabilidade relativa
# 9.342946336524204 deles implica
# 7.145721759187985 possui poros
# 7.145721759187985 poros capilares
# 9.342946336524204 formam-se pressões
# 7.263504794844368 nível d
# 8.649799155964258 d água
# 8.649799155964258 água desce
# 6.142913599457484 tensão interfacial
# 6.777996979062667 exerce sobre
# 6.570357614284423 fases sólida
# 6.703889006908946 desta interface
# 7.551186867296149 glóbulos praticamente
# 9.342946336524204 praticamente imóveis
# 6.858039686736205 forte tendência
# 7.040361243530159 algumas alterações
# 8.649799155964258 poro adjacente
# 6.634896135421995 existem muitos
# 6.570357614284423 subseqüente mobilização
# 7.551186867296149 dentre eles
# 7.040361243530159 fluidos percolantes
# 6.570357614284423 pode-se utilizar
# 6.45257457862804 número capilar
# 8.649799155964258 numero bond
# 7.040361243530159 nc consiste
# 6.45257457862804 força capilar
# 8.244334047856094 força gravitacional
# 6.010741826349001 vazão especifica
# 7.956651975404314 µ= viscosidade
# 6.703889006908946  ''
# 6.703889006908946 '' á
# 8.649799155964258 raio representativo
# 7.551186867296149 valor desses
# 8.244334047856094 desses números
# 6.858039686736205 glóbulos trapeados
# 6.45257457862804 especialmente diferente
# 7.145721759187985 forte molhabilidade
# 8.649799155964258 fina camada
# 7.040361243530159 fica imóvel
# 7.551186867296149 ela transmite
# 9.342946336524204 micro tubulação
# 7.551186867296149 ficar imóvel
# 7.551186867296149 tudo depende
# 7.956651975404314 escoa pelos
# 6.570357614284423 pelos filmes
# 6.634896135421995 grãos próximos
# 7.551186867296149 glóbulos aprisionados
# 6.703889006908946 caso haja
# 6.164892506176259 haja tempo
# 9.342946336524204 região circundante
# 7.040361243530159 esta troca
# 7.263504794844368 vaporização preferencial
# 6.298423898800781 co2 faz
# 7.956651975404314 intensidade iônica
# 6.164892506176259 outras substâncias
# 6.164892506176259 principalmente descrita
# 6.45257457862804 pressão parcial
# 6.1240705116560035 composto químico
# 6.298423898800782 diretamente proporcional
# 6.45257457862804 descreve tal
# 6.53958595561767 varia significativamente
# 7.551186867296149 adsorção competitiva
# 6.347214062970213 previamente sorvidos
# 7.733508424090104 partículas sólidas
# 7.040361243530159 sólidas apresentam
# 6.858039686736205 grande complexidade
# 9.342946336524204 curvas denominadas
# 9.342946336524204 denominadas isotermas
# 6.164892506176259 varia tanto
# 7.0279387235316015 matéria orgânica
# 6.164892506176259 previamente sorvida
# 7.551186867296149 diversas equações
# 9.342946336524204 modelar matematicamente
# 8.244334047856094 freundlich descreve
# 8.244334047856094 descreve s1
# 7.263504794844368 tem inclinação
# 9.342946336524204 inclinação zero
# 6.010741826349001 alguns cátions
# 8.244334047856094 substâncias húmicas
# 9.342946336524204 estimar preliminarmente
# 7.733508424090104 partição solo/água
# 6.398507357357764 relação empírica
# 7.733508424090104 partição octanol/água
# 7.145721759187985 matéria orgânica/água
# 8.244334047856094 pah onde
# 7.551186867296149 permite simplificar
# 7.956651975404314 outro aspecto
# 8.244334047856094 ignorado nesta
# 8.244334047856094 nesta simplificação
# 6.398507357357764 diferentes capacidades
# 6.570357614284423 vários tipos
# 7.733508424090104 ácidos fúlvicos
# 7.733508424090104 ácidos húmicos
# 7.956651975404314 suas conformações
# 9.342946336524204 conformações físicas
# 6.570357614284423 infiltra apresenta
# 6.164892506176259 poluentes menores
# 7.040361243530159 porção hidrofóbica
# 7.040361243530159 porção hidrofílica
# 6.8862105637029005 porção apolar
# 6.010741826349001 iônicos utilizados
# 7.956651975404314 utilizados comercialmente
# 8.649799155964258 comercialmente incluem
# 8.649799155964258 incluem ésteres
# 9.342946336524204 ésteres sulfatados
# 7.733508424090104 ácidos graxos
# 8.649799155964258 produzidos quimicamente
# 7.145721759187985 estrutura básica
# 6.347214062970213 polares aos
# 7.397036187468891 agregam formando
# 6.010741826349001 formando micelas
# 8.649799155964258 micelar crítica
# 7.551186867296149 cadeias apolares
# 6.858039686736205 grupos polares
# 8.244334047856094 formam pontes
# 6.010741826349001 distribuir nas
# 6.010741826349001 nas interfaces
# 7.263504794844368 fases fluidas
# 6.398507357357764 diferentes graus
# 6.45257457862804 filme molecular
# 7.551186867296149 molecular ordenado
# 6.010741826349001 ordenado nas
# 8.649799155964258 interfaces reduz
# 7.040361243530159 responsável pelas
# 7.040361243530159 pelas propriedades
# 8.649799155964258 propriedades únicas
# 6.164892506176259 micelas provoca
# 6.570357614284423 chamada solubilidade
# 6.570357614284423 solubilidade aparente
# 8.244334047856094 pequenas bolhas
# 6.45257457862804 estas bolhas
# 8.649799155964258 liquido predominante
# 8.649799155964258 termodinamicamente estável
# 6.634896135421995 solubilização haver
# 6.570357614284423 haver apenas
# 6.164892506176259 emulsão naturalmente
# 6.298423898800782 quais constituem
# 7.551186867296149 constituem formações
# 7.956651975404314 formações aderidas
# 6.347214062970213 podendo estar
# 7.733508424090104 estar ligadas
# 7.263504794844368 deixando livre
# 6.347214062970213 porção polar
# 8.244334047856094 nesta última
# 8.244334047856094 última situação
# 6.858039686736205 liguem-se às
# 7.956651975404314 apolares expostas
# 6.047109470519875 estrutura conhecida
# 8.244334047856094 ocorrência destas
# 8.649799155964258 destas formações
# 9.342946336524204 vice versa
# 6.858039686736205 alterada devido
# 8.244334047856094 tensões interfaciais
# 8.649799155964258 gravitacional exercida
# 6.634896135421995 estar prioritariamente
# 6.251903883165888 superficial água/ar
# 6.945051063725834 alterando significativamente
# 6.945051063725834 superficial óleo/ar
# 8.244334047856094 tensões mostradas
# 7.145721759187985 água/óleo ficar
# 6.047109470519875 aumente sua
# 6.570357614284423 deve promover
# 6.251903883165888 1972 já
# 7.733508424090104 estar preso
# 6.509732992467988 preso pelo
# 6.570357614284423 interfacial óleo/água
# 7.263504794844368 água/ar facilitam
# 6.945051063725834 significativamente acelerado
# 8.244334047856094 aditivos monoméricos
# 7.551186867296149 notável alteração
# 6.777996979062667 discute sobre
# 8.244334047856094 está aprisionada
# 8.244334047856094 atuando prioritariamente
# 6.347214062970213 contato direto
# 6.010741826349001 vazão efetivamente
# 8.649799155964258 poços parcial
# 8.649799155964258 totalmente penetrantes
# 8.649799155964258 capilaridade predominam
# 8.649799155964258 fraca correspondência
# 7.956651975404314 efluente drenado
# 7.397036187468891 visem investigar
# 7.551186867296149 preferencialmente devem
# 6.45257457862804 infiltração próximas
# 8.244334047856094 difícil reproduzir
# 8.244334047856094 reproduzir tais
# 8.244334047856094 sólido sorver
# 9.342946336524204 carregadas eletronegativamente
# 6.703889006908946 apolar exposta
# 6.298423898800781 neutralizam este
# 7.956651975404314 pelos sítios
# 9.342946336524204 sítios ativos
# 7.956651975404314 ativos apolares
# 6.45257457862804 bem acima
# 7.263504794844368 pode-se esperar
# 6.570357614284423 poluentes altamente
# 6.703889006908946 altamente hidrofóbicos
# 8.244334047856094 nem sempre
# 6.010741826349001 podendo ocorrer
# 6.858039686736205 consequentemente difícil
# 8.244334047856094 difícil previsibilidade
# 8.649799155964258 vasta ecologia
# 6.634896135421995 influenciada pelas
# 9.342946336524204 diagrama esquemático
# 7.145721759187985 biota típica
# 7.040361243530159 contendo partículas
# 7.733508424090104 partículas minerais
# 9.342946336524204 [ bactéria
# 7.263504794844368 fungos saprofíticos
# 9.342946336524204 protozoário ciliado
# 7.145721759187985 orgânica decorre
# 6.634896135421995 materiais adicionados
# 8.649799155964258 gradualmente transformados
# 9.342946336524204 húmus rico
# 7.397036187468891 estes variados
# 8.649799155964258 variados componentes
# 7.551186867296149 componentes formam
# 8.244334047856094 formam agregados
# 9.342946336524204 agregados heterogêneos
# 7.956651975404314 vários tamanhos
# 6.703889006908946 estado avançado
# 7.145721759187985 orgânica mineralizada
# 6.207452120595055 mineralizada forma
# 7.733508424090104 ácidos fúlvico
# 6.398507357357764 diferentes estratégias
# 9.342946336524204 estratégias funcionais
# 8.649799155964258 complexa matriz
# 8.649799155964258 matriz física
# 7.040361243530159 menos suscetíveis
# 9.342946336524204 tornarem-se alimento
# 6.047109470519875 sua imediata
# 9.342946336524204 imediata vizinhança
# 7.551186867296149 permite dividir
# 6.858039686736205 aderem às
# 8.244334047856094 atualmente sabe-se
# 6.398507357357764 ligam diferentes
# 8.649799155964258 transformam efetivamente
# 6.398507357357764 diferentes organismos
# 7.733508424090104 têm revelado
# 7.733508424090104 existem significativas
# 9.342946336524204 significativas diferenças
# 7.551186867296149 única espécie
# 6.634896135421995 muitas espécies
# 6.347214062970213 superfície exposta
# 7.733508424090104 biofilmes bacterianos
# 7.040361243530159 apresentam inter-relações
# 6.945051063725834 dependência muito
# 7.551186867296149 dentro dessas
# 8.649799155964258 dessas comunidades
# 6.347214062970213 energia disponível
# 7.551186867296149 acionar rotas
# 7.551186867296149 rotas metabólicas
# 7.263504794844368 células adjacentes
# 6.858039686736205 mesma população
# 6.570357614284423 produtos degradados
# 7.733508424090104 produzir novas
# 6.45257457862804 estrutura química
# 6.251903883165888 profunda influência
# 7.145721759187985 microrganismos metabolizarem
# 7.551186867296149 metabolizarem estas
# 6.858039686736205 respeito às
# 6.858039686736205 rapidamente biodegradados
# 6.703889006908946 médio peso
# 7.214714630674937 peso molecular
# 8.244334047856094 alcoóis exemplos
# 9.342946336524204 facilmente biodegradáveis
# 6.703889006908946 aromáticos tendem
# 6.298423898800782 anéis aromáticos
# 7.397036187468891 aromáticos fundidos
# 7.263504794844368 somente provaram
# 7.551186867296149 provaram tal
# 8.649799155964258 rota metabólica
# 7.445826351638323 comunidade microbiana
# 7.956651975404314 microbiana envolvida
# 6.740256651079821 microrganismos primários
# 7.551186867296149 aqueles capazes
# 6.777996979062667 principal fornecido
# 7.956651975404314 produtos liberados
# 7.956651975404314 liberados pelos
# 6.45257457862804 pelos microrganismos
# 7.733508424090104 comunidade cientifica
# 6.858039686736205 geral aceita
# 8.244334047856094 nenhuma espécie
# 7.956651975404314 microorganismo degrada
# 8.649799155964258 degrada completamente
# 8.649799155964258 completamente nenhum
# 6.45257457862804 metabólicas apresentadas
# 7.145721759187985 apresentadas ocorrem
# 6.570357614284423 múltiplos aceptores
# 7.956651975404314 aceptores finais
# 6.703889006908946 microorganismos usam
# 7.551186867296149 aceptor termodinamicamente
# 6.45257457862804 favorável até
# 6.298423898800781 este tenha
# 6.047109470519875 tenha sua
# 8.649799155964258 disponibilidade reduzida
# 6.858039686736205 sejam utilizados
# 7.956651975404314 utilizados seqüencialmente
# 9.342946336524204 no3 feooh
# 9.342946336524204 so4 -2
# 7.397036187468891 conforme ilustra
# 7.397036187468891 receptor final
# 8.244334047856094 respiração aeróbia
# 6.570357614284423 condições aeróbias
# 9.342946336524204 estruturas moleculares
# 9.342946336524204 moleculares necessárias
# 6.570357614284423 nutrientes necessários
# 7.263504794844368 macro nutrientes
# 9.342946336524204 recursos limitados
# 7.145721759187985 tipicamente descrito
# 6.634896135421995 curva característica
# 9.342946336524204 sistemas fechados
# 6.9758227223925875 modelos cinéticos
# 6.21368267034569 crescimento celular
# 7.263504794844368 possíveis inibidores
# 6.164892506176259 modelos comumente
# 8.244334047856094 comumente usados
# 7.145721759187985 andrews haldane
# 6.45257457862804 monod descreve
# 6.347214062970213 têm sido
# 6.570357614284423 sido desenvolvidos
# 6.164892506176259 único substrato
# 7.445826351638323 múltiplos substratos
# 7.263504794844368 podendo chegar
# 6.084849798502723 taxa específica
# 7.040361243530159 substratos ks
# 6.634896135421995 num determinado
# 6.251903883165888 principais limitações
# 6.703889006908946 limitações desta
# 6.945051063725834 técnica refere-se
# 8.649799155964258 envolvem misturas
# 6.398507357357764 comportamento microbiológico
# 7.733508424090104 teste relativamente
# 9.342946336524204 relativamente simples
# 7.733508424090104 interesse separadamente
# 7.040361243530159 processos físico-quimicos
# 7.040361243530159 pouco prático
# 7.956651975404314 avaliações preliminares
# 6.703889006908946 microorganismos heterotróficos
# 8.649799155964258 unidades formadoras
# 6.45257457862804 amplamente utilizada
# 7.551186867296149 grandes limitações
# 6.858039686736205 ocasionando grande
# 6.703889006908946 hidrogênio desta
# 6.298423898800782 aceptor final
# 7.733508424090104 estar reagindo
# 7.551186867296149 reagindo rapidamente
# 7.145721759187985 impede seu
# 7.145721759187985 seu acumulo
# 6.207452120595055 havendo assim
# 6.084849798502723 real capacidade
# 6.945051063725834 já conhecidos
# 7.263504794844368 comparando-se suas
# 6.207452120595055 forma grosseira
# 6.858039686736205 ocorrendo grande
# 6.634896135421995 ainda primariamente
# 6.634896135421995 primariamente avaliar
# 8.244334047856094 alcanos ramificados
# 7.551186867296149 alcanos lineares
# 7.956651975404314 lineares tende
# 6.1240705116560035 estimada através
# 6.945051063725834 técnicas biomoleculares
# 9.342946336524204 terminal fragment
# 9.342946336524204 fragment length
# 9.342946336524204 length polymorphism
# 9.342946336524204 denaturing gradient
# 9.342946336524204 gradient gel
# 9.342946336524204 gel electrophoresis
# 9.342946336524204 polymerase chain
# 9.342946336524204 chain reaction
# 7.040361243530159 análise quantitativa
# 7.551186867296149 espécies bacterianas
# 7.956651975404314 serem cultiváveis
# 6.207452120595055 forma indireta
# 6.347214062970213 biomassa pelas
# 6.945051063725834 técnicas tradicionais
# 7.551186867296149 extraem diretamente
# 8.649799155964258 material genético
# 7.040361243530159 genético existente
# 7.551186867296149 biomoleculares permitem
# 7.263504794844368 ecologia microbiana
# 6.45257457862804 biota capaz
# 7.551186867296149 degradar certo
# 7.040361243530159 certo grupo
# 7.733508424090104 pouco difundidas
# 9.342946336524204 preocupações levantadas
# 7.263504794844368 in vitro
# 7.263504794844368 vitro tem
# 6.570357614284423 tem sido
# 7.551186867296149 certos intermediários
# 9.342946336524204 particularmente di-hidrodióis
# 8.649799155964258 sedimentos sugerem
# 6.858039686736205 rapidamente transformados
# 6.777996979062667 revisão sobre
# 6.047109470519875 microrganismos capazes
# 7.145721759187985 estão potencialmente
# 9.342946336524204 potencialmente localizados
# 9.342946336524204 embora apresentem
# 8.244334047856094 apresentem grandes
# 7.551186867296149 grandes variações
# 7.956651975404314 população aumenta
# 6.010741826349001 aumenta após
# 7.145721759187985 microrganismos hidrocarbonoclásticos
# 8.244334047856094 hidrocarbonoclásticos dentro
# 6.164892506176259 microbiana depende
# 6.703889006908946 poluídos estes
# 6.047109470519875 microrganismos constituem
# 7.956651975404314 ecossistemas poluídos
# 6.084849798502723 poluídos podem
# 6.084849798502723 podem chegar
# 7.733508424090104 constituir 100
# 8.649799155964258 reconhecidamente degradadoras
# 6.858039686736205 naturais mostraram
# 6.45257457862804 bactérias isoladas
# 6.858039686736205 grande gama
# 6.047109470519875 evitando seu
# 6.047109470519875 seu acúmulo
# 7.040361243530159 aos metabolitos
# 6.509732992467988 equação exponencial
# 9.342946336524204 subseqüentes ordens
# 6.858039686736205 primeira ordem
# 6.45257457862804 ordem comumente
# 6.45257457862804 comumente utilizada
# 8.649799155964258 meia vida
# 7.551186867296149 tal extrapolação
# 7.263504794844368 extrapolação tem
# 7.263504794844368 sido aceita
# 6.45257457862804 esse modelo
# 7.956651975404314 geralmente usado
# 6.570357614284423 apenas conseguem
# 9.342946336524204 conseguem absorver
# 6.634896135421995 entretanto outros
# 6.703889006908946 certo ponto
# 6.703889006908946 ponto disponíveis
# 6.703889006908946 apesar disso
# 6.45257457862804 estão disponíveis
# 7.551186867296149 absorção direta
# 7.040361243530159 menos biodisponiveis
# 6.634896135421995 dissolução representam
# 7.040361243530159 representam processos
# 7.040361243530159 processos essenciais
# 7.040361243530159 substratos inicialmente
# 7.263504794844368 inicialmente adsorvidos
# 7.551186867296149 fator limitante
# 6.010741826349001 hidrofóbicos geralmente
# 6.207452120595055 aumentando assim
# 6.570357614284423 direta pelos
# 8.244334047856094 amplamente estudada
# 7.040361243530159 membrana celular
# 8.649799155964258 componentes lipídicos
# 7.956651975404314 enzimas fundamentais
# 7.397036187468891 três mecanismos
# 9.342946336524204 polímeros extracelulares
# 9.342946336524204 extracelulares responsáveis
# 7.956651975404314 própria atividade
# 7.551186867296149 fator crucial
# 6.347214062970213 catiônicos apresentam
# 7.733508424090104 ambientes ácidos
# 6.703889006908946 microorganismos degradadores
# 7.551186867296149 totalmente explicado
# 7.551186867296149 fatores positivos
# 7.956651975404314 representar negativos
# 7.551186867296149 positivos consistem
# 7.551186867296149 evitando impactos
# 8.649799155964258 impactos ambientais
# 9.342946336524204 ambientais posteriores
# 6.509732992467988 condição positiva
# 7.956651975404314 degradados cometabolicamente
# 6.164892506176259 últimos 20
# 6.164892506176259 20 anos
# 6.047109470519875 sua origem
# 7.040361243530159 80 iniciaram-se
# 6.858039686736205 especialmente aqueles
# 7.551186867296149 pesquisas relativas
# 7.040361243530159 consolidaram esta
# 8.649799155964258 mundialmente difundida
# 7.397036187468891 vezes conflitantes
# 6.010741826349001 alguns pesquisadores
# 7.551186867296149 utilizaram biossurfactantes
# 8.244334047856094 bastante limitada
# 9.342946336524204 limitada economicamente
# 7.551186867296149 ii 1412-56
# 7.956651975404314 predominantemente mineral
# 6.347214062970213 outro orgânico
# 7.551186867296149 estudados independentemente
# 7.956651975404314 alfonic 810-60
# 7.956651975404314 suas máximas
# 7.263504794844368 novel ii
# 6.347214062970213 bem menos
# 7.040361243530159 menos acentuado
# 7.733508424090104 obtidos concluiu-se
# 8.244334047856094 biodegração dependem
# 6.1240705116560035 creosoto proveniente
# 8.649799155964258 consórcios microbianos
# 7.551186867296149 microbianos naturalmente
# 7.551186867296149 naturalmente adaptados
# 7.040361243530159 estudo utilizou
# 6.634896135421995 creosoto apresentar
# 7.551186867296149 apresentar dezenas
# 6.703889006908946 alto peso
# 6.207452120595055 instante inicial
# 9.342946336524204 toxidade advinda
# 7.551186867296149 advinda diretamente
# 6.251903883165888 apresentou razoável
# 7.733508424090104 creosoto contém
# 6.634896135421995 contém outros
# 7.733508424090104 estar provocando
# 6.509732992467988 sistema solo-água
# 6.164892506176259 somente aquoso
# 8.649799155964258 pseudomonas aeruginosa
# 7.551186867296149 espécie conhecidamente
# 7.956651975404314 conhecidamente capaz
# 6.251903883165888 muito baixa
# 7.956651975404314 autores sugerem
# 6.509732992467988 sistema aquos
# 9.342946336524204 progressivamente inibida
# 6.164892506176259 15 dias
# 7.551186867296149 dias todo
# 6.529535619764168 neste estudo
# 8.649799155964258 motivo claro
# 7.733508424090104 ter ocorrido
# 7.733508424090104 neste último
# 6.703889006908946 último caso
# 6.45257457862804 biota degrada
# 7.551186867296149 degrada preferencialmente
# 9.342946336524204 polychloride biphenyl
# 8.649799155964258 pseudomonas sp
# 7.733508424090104 aniônicos estimularam
# 6.010741826349001 acentuada nas
# 7.551186867296149 coluna proporcionou
# 6.634896135421995 via solubilização
# 6.298423898800782 baixo peso
# 8.649799155964258 sapogenat t-300
# 6.347214062970213 200 horas
# 9.342946336524204 hpas passaram
# 7.145721759187985 claramente demonstrou
# 6.047109470519875 sua eficácia
# 9.342946336524204 akopal n-300
# 7.263504794844368 1997 cho
# 7.145721759187985 compactados demonstraram
# 7.328043315981939 tween 80
# 7.956651975404314 resultado permitiu
# 6.347214062970213 permitiu aos
# 6.347214062970213 aos autores
# 8.649799155964258 autores estabelecer
# 7.551186867296149 modelo cinético
# 7.145721759187985 demonstraram exatamente
# 6.777996979062667 duas vazões
# 6.267171355296677 50 ml/min
# 6.347214062970213 napl aproximadamente
# 7.956651975404314 tendência clara
# 7.733508424090104 ter demonstrado
# 6.251903883165888 demonstrado influência
# 6.207452120595055 dois biosurfactantes
# 6.347214062970213 assemelham aos
# 6.251903883165888 apresentou melhor
# 6.777996979062667 bancada podem
# 6.570357614284423 dadas condições
# 9.342946336524204 obserevações degração
# 7.263504794844368 uso observações
# 9.342946336524204 observações crescento
# 7.956651975404314 crescento microbiano
# 7.263504794844368 microbiano ?
# 6.509732992467988 x inconclusivo
# 6.509732992467988 inconclusivo x
# 7.551186867296149 todos pahs
# 7.263504794844368 apresentaram estilimulação
# 6.207452120595055 fenantreno veio
# 6.858039686736205 altas /
# 8.244334047856094 / variou
# 9.342946336524204 observando ocoreu
# 6.634896135421995 nem sim
# 7.551186867296149 nem estimulo
# 6.509732992467988 x motivos
# 7.956651975404314 investigação experimental
# 7.551186867296149 experimental deste
# 6.45257457862804 deste trabalho
# 6.45257457862804 trabalho consistiu
# 6.164892506176259 ensaios prévios
# 6.45257457862804 utilizado visou
# 7.551186867296149 visou simular
# 6.945051063725834 já desenvolvida
# 8.649799155964258 terreno reconhecidamente
# 6.251903883165888 camada superficial
# 7.956651975404314 usualmente considerada
# 6.8862105637029005 características geotécnicas
# 6.347214062970213 análise química
# 7.397036187468891 ponto selecionado
# 8.244334047856094 decidiu-se executar
# 6.347214062970213 área circular
# 6.207452120595055 totalizando assim
# 7.956651975404314 impossibilidade mecânica
# 7.956651975404314 trado helicoidal
# 9.342946336524204 helicoidal manual
# 6.347214062970213 amostragem indeformada
# 8.649799155964258 sondaterra @
# 8.244334047856094 anéis metálicos
# 6.634896135421995 garantir vedação
# 7.956651975404314 consequente manutenção
# 8.244334047856094 filme plástico
# 7.145721759187985 papel alumínio
# 6.703889006908946 mantivesse abaixo
# 9.342946336524204 amostrador tubular
# 9.342946336524204 tubular aberto
# 7.551186867296149 00 metro
# 8.649799155964258 liner descartável
# 8.244334047856094 recipiente térmico
# 8.649799155964258 térmico resfriado
# 6.347214062970213 preliminares logo
# 6.164892506176259 submetidas às
# 8.649799155964258 htp fracionado
# 7.040361243530159 usepa 8260b
# 7.040361243530159 usepa 8270d
# 6.084849798502723 sondagem ss-02
# 6.858039686736205 condutividade elétrica
# 6.858039686736205 tph medidas
# 6.010741826349001 densidade média
# 8.649799155964258 8376 g/cm³
# 8.244334047856094 vazios obteve-se
# 7.551186867296149 investigação laboratorial
# 7.551186867296149 mostrou consideravelmente
# 8.649799155964258 consideravelmente heterogêneo
# 7.263504794844368 heterogêneo tanto
# 6.347214062970213 geotécnicas preliminares
# 7.551186867296149 decidiu-se organizar
# 6.570357614284423 qual relacionado
# 6.703889006908946 procurou-se evitar
# 8.244334047856094 alguma característica
# 7.551186867296149 característica intrínseca
# 6.777996979062667 sondagem interferisse
# 6.164892506176259 ensaio respirométrico
# 6.298423898800781 realizaram-se também
# 6.480745455594736 sondagens ss-01
# 6.991571079360727 sondagens ss-31
# 6.858039686736205 tipo usp
# 7.956651975404314 marca cinética
# 6.570357614284423 alto grau
# 6.164892506176259 baixo grau
# 7.263504794844368 pureza visou
# 9.342946336524204 tornaria financeiramente
# 9.342946336524204 financeiramente proibitivo
# 7.733508424090104 36 g/l
# 6.703889006908946 evitar perdas
# 7.551186867296149 desenvolvido especialmente
# 6.703889006908946 três partes
# 6.251903883165888 partes principais
# 7.328043315981939 mariotte adaptado
# 6.298423898800781 carga hidráulica
# 6.347214062970213 mantivesse constante
# 6.703889006908946 baixa densidade
# 7.733508424090104 anel metálico
# 6.4903149066108865 corpo principal
# 8.244334047856094 qualquer interferência
# 7.263504794844368 melhor distribuição
# 8.649799155964258 pedras porosas
# 7.551186867296149 diâmetro igual
# 6.858039686736205 acopladas às
# 7.551186867296149 papel filtro
# 7.397036187468891 45 µm
# 7.956651975404314 pedra porosa
# 6.298423898800782 evitar qualquer
# 6.703889006908946 contaminação cruzada
# 7.263504794844368 utilizadas pedras
# 6.509732992467988 composta pelo
# 7.956651975404314 corpo central
# 8.244334047856094 central constituído
# 6.207452120595055 dois funis
# 9.342946336524204 unir essas
# 8.649799155964258 essas peças
# 7.145721759187985 essa estrutura
# 7.956651975404314 seção circular
# 8.649799155964258 circular vazada
# 6.858039686736205 parafusos tipo
# 6.858039686736205 tipo rosca
# 6.634896135421995 rosca sem
# 7.551186867296149 montada está
# 7.551186867296149 está apresentada
# 6.45257457862804 apoiar até
# 7.040361243530159 250 ml
# 8.649799155964258 utilizou-se fita
# 7.956651975404314 utilizados pequenos
# 9.342946336524204 pequenos pedaços
# 6.45257457862804 ar condicionado
# 9.342946336524204 condicionado digital
# 9.342946336524204 detergente neutro
# 6.298423898800782 deionizada seguida
# 7.040361243530159 novamente enxágue
# 7.956651975404314 devidamente pesado
# 9.342946336524204 balões volumétricos
# 8.244334047856094 materiais limpos
# 6.634896135421995 soluções preparadas
# 6.858039686736205 coluna d
# 7.263504794844368 então colocada
# 6.945051063725834 já posicionado
# 6.777996979062667 posicionado sobre
# 7.397036187468891 funil inferior
# 6.945051063725834 vez montado
# 7.733508424090104 mariotte ficasse
# 6.570357614284423 ficasse apenas
# 6.22943102731383 cm acima
# 7.551186867296149 nesta posição
# 6.047109470519875 saturação durou
# 6.010741826349001 durou 10
# 6.945051063725834 vez iniciado
# 6.509732992467988 interrompido quando
# 6.509732992467988 quando apresentava
# 7.551186867296149 apresentava risco
# 6.164892506176259 volume meta
# 6.858039686736205 meta durante
# 6.398507357357764 possível acompanhar
# 8.649799155964258 porosidades médias
# 6.777996979062667 médias indeformadas
# 6.047109470519875 poros totais
# 7.145721759187985 poros efetivos
# 7.551186867296149 porosidades totais
# 7.263504794844368 era retirada
# 9.342946336524204 frasco âmbar
# 6.347214062970213 500 ml
# 6.347214062970213 200 ml
# 8.649799155964258 posição horizontal
# 7.145721759187985 seu interior
# 6.164892506176259 então removido
# 6.010741826349001 10 minutos
# 6.347214062970213 novamente pesado
# 7.551186867296149 rapidamente homogeneizado
# 7.397036187468891 30 gramas
# 7.956651975404314 outro armazenou
# 6.945051063725834 vez terminada
# 6.164892506176259 correspondentes às
# 7.733508424090104 soluções pesquisadas
# 7.040361243530159 aproximadamente 70g
# 6.347214062970213 logo antes
# 8.649799155964258 balanço utilizaram-se
# 7.263504794844368 base seca
# 6.047109470519875 percentual removido
# 7.733508424090104 quantificação diferiram
# 7.263504794844368 realizado teve
# 6.398507357357764 nbr 14
# 7.733508424090104 algumas modificações
# 8.244334047856094 modificações apresentadas
# 6.164892506176259 ensaios respirométricos
# 6.45257457862804 apresentavam contaminadas
# 9.342946336524204 aparência esbranquiçada
# 9.342946336524204 descrições geológicas
# 9.342946336524204 terem reportado
# 6.164892506176259 reportado presença
# 6.010741826349001 adicionou-se hcl
# 7.551186867296149 ela continha
# 8.244334047856094 continha esse
# 8.649799155964258 poderia gerar
# 7.263504794844368 elevada produção
# 9.342946336524204 descrição geológica
# 9.342946336524204 geológica estava
# 9.342946336524204 estava correta
# 7.397036187468891 nitrogênio kjeldahl
# 6.945051063725834 kjeldahl total
# 9.342946336524204 sm 4500
# 6.703889006908946 4500 b
# 7.040361243530159 usepa 6010c
# 6.298423898800782 embrapa 1999
# 6.084849798502723 dessas análises
# 6.740256651079821 método respirométrico
# 7.551186867296149 respirométrico aplicado
# 6.777996979062667 mas necessitou
# 8.649799155964258 sulfato amônio
# 7.956651975404314 amônio pa
# 7.733508424090104 destilada adicionada
# 7.551186867296149 úmido correspondente
# 6.570357614284423 umidade determinados
# 8.244334047856094 determinados anteriormente
# 6.570357614284423 umidade próxima
# 6.347214062970213 conclusão obtida
# 6.45257457862804 poros calculado
# 7.956651975404314 283/1999 estabelece
# 6.858039686736205 deve ficar
# 9.342946336524204 arbitrariamente escolheu-se
# 9.342946336524204 escolheu-se corrigir
# 6.570357614284423 era necessário
# 7.263504794844368 necessário adicionar
# 6.398507357357764 possível secar
# 9.342946336524204 mesmas perderiam
# 6.45257457862804 trabalho visa
# 6.207452120595055 impossibilitando assim
# 7.397036187468891 atingir 30
# 6.398507357357764 n desejada
# 6.45257457862804 estão apresentados
# 6.416206934457165 respirômetros lavados
# 9.342946336524204 seus respectivos
# 6.703889006908946 respectivos respirômetros
# 6.703889006908946 respirômetros vedados
# 7.397036187468891 conforme determina
# 9.342946336524204 cal sodada
# 6.858039686736205 substituição vem
# 8.649799155964258 reagentes necessários
# 6.047109470519875 respirométrico utilizado
# 6.047109470519875 utilizado consistiu
# 6.298423898800781 co2 produzido
# 6.164892506176259 tempo exposto
# 6.570357614284423 então determinou-se
# 6.075280347486572 co2 produzida
# 6.45257457862804 manteve até
# 6.298423898800782 decidiu-se investigar
# 6.398507357357764 comportamento anômalo
# 8.649799155964258 anômalo observado
# 6.517113099765611 primeiras semanas
# 6.703889006908946 repetiria caso
# 6.703889006908946 caso fossem
# 7.733508424090104 fossem adicionados
# 8.244334047856094 gás carbônico
# 8.649799155964258 avaliada semanalmente
# 9.342946336524204 padronizado contra
# 8.649799155964258 contra carbonato
# 7.040361243530159 padrão primário
# 6.298423898800781 co2 consome
# 6.777996979062667 consome duas
# 6.010741826349001 realizado conforme
# 7.551186867296149 * fhcl
# 7.551186867296149 fhcl *
# 8.649799155964258 1000 *2
# 6.703889006908946 hcl gasto
# 9.342946336524204 molaridade teórica
# 7.145721759187985 1n /
# 6.298423898800781 co2 produzidas
# 9.342946336524204 dele subtraindo
# 7.145721759187985 determinar quantos
# 7.956651975404314 quantos mols
# 6.45257457862804 norma aplicada
# 6.45257457862804 c degradada
# 7.040361243530159 degradado fica
# 7.040361243530159 celular resultante
# 6.084849798502723 realizadas análises
# 6.570357614284423 cot antes
# 7.263504794844368 pode-se correlacionar
# 7.956651975404314 possíveis origens
# 6.251903883165888 significativa heterogeneidade
# 7.040361243530159 dados geotécnicos
# 9.342946336524204 ss-03 ss-04
# 9.342946336524204 ss-04 ss-05
# 6.570357614284423 isso promover
# 7.263504794844368 possíveis impactos
# 6.164892506176259 posterior biorremediação
# 6.251903883165888 demonstram significativa
# 8.649799155964258 limites detectáveis
# 6.945051063725834 técnica analítica
# 6.570357614284423 considera tanto
# 6.164892506176259 tabela correspondem
# 7.040361243530159 correspondem aos
# 6.347214062970213 aos casos
# 7.397036187468891 ficou abaixo
# 8.244334047856094 limite máximo
# 7.145721759187985 percentual precedido
# 6.207452120595055 estabelecendo-se assim
# 6.298423898800782 limite inferior
# 7.733508424090104 removeu pouco
# 6.207452120595055 forma consistente
# 6.084849798502723 r u
# 6.164892506176259 u d
# 6.509732992467988 52 470
# 9.342946336524204 ss-01/4 ss-03/1
# 9.342946336524204 ss-03/1 ss-04/2
# 9.342946336524204 ss-04/2 ss-05/3
# 6.298423898800781 co2 gerados
# 6.010741826349001 gerados nas
# 6.703889006908946 quais incluem
# 6.634896135421995 semanas seguintes
# 6.251903883165888 significativa consistência
# 8.649799155964258 triplicata ficaram
# 9.342946336524204 ficaram razoavelmente
# 8.244334047856094 razoavelmente próximos
# 8.244334047856094 próximos uns
# 6.634896135421995 triplicatas têm
# 6.634896135421995 têm suficiente
# 8.244334047856094 suficiente homogeneidade
# 6.164892506176259 600 tempo
# 6.777996979062667 biodegradaçãao longo
# 7.040361243530159 aos demais
# 7.733508424090104 tornando-se novamente
# 7.040361243530159 novamente ligeiramente
# 6.010741826349001 nas ultimas
# 6.251903883165888 scna comparando-se
# 6.398507357357764 possível confirmar
# 8.649799155964258 massas acumuladas
# 8.649799155964258 quase todo
# 6.398507357357764 comportamento resultou
# 8.649799155964258 degradações ligeiramente
# 8.649799155964258 ligeiramente inferiores
# 6.858039686736205 inferiores às
# 6.164892506176259 às observadas
# 6.398507357357764 possível afirmar
# 7.551186867296149 afirmar tal
# 8.649799155964258 correspondentes estatísticas
# 6.858039686736205 75 3ª
# 7.040361243530159 68 5ª
# 7.145721759187985 54 6ª
# 7.263504794844368 75 7ª
# 6.45257457862804 87 21
# 6.047109470519875 65 23
# 7.397036187468891 97 26
# 6.347214062970213 29 69
# 6.858039686736205 55 75
# 7.263504794844368 desvio desvio
# 7.040361243530159 desvio padrão
# 6.298423898800782 77 3ª
# 6.858039686736205 86 4ª
# 6.010741826349001 42 43
# 6.047109470519875 87 31
# 6.703889006908946 26 9ª
# 6.010741826349001 09 35
# 6.570357614284423 89 10ª
# 6.703889006908946 respirômetros expressos
# 7.145721759187985 percentual acumulado
# 6.634896135421995 destacam ainda
# 6.207452120595055 forma inversa
# 6.570357614284423 condições biológicas
# 9.342946336524204 biológicas adaptadas
# 8.649799155964258 realista acarreta
# 6.010741826349001 controlar alguns
# 7.551186867296149 isto torna
# 6.251903883165888 muito complexo
# 6.398507357357764 possível isolar
# 6.570357614284423 isolar apenas
# 6.703889006908946 apesar dessa
# 9.342946336524204 dessa dificuldade
# 7.145721759187985 fundamental realizar
# 6.164892506176259 naturalmente contaminados
# 8.649799155964258 assemelham àquelas
# 9.342946336524204 àquelas obtidas
# 6.703889006908946 contaminação artificial
# 7.263504794844368 artificial e/ou
# 6.570357614284423 e/ou inoculação
# 8.649799155964258 culturas bacterianas
# 7.956651975404314 bacterianas específicas
# 7.551186867296149 experimentos deste
# 6.45257457862804 naturalmente adaptado
# 6.164892506176259 houve nenhum
# 6.703889006908946 vista prático
# 7.263504794844368 ensaio cumpriu
# 7.145721759187985 cumpriu seu
# 7.551186867296149 mostrou-se bastante
# 6.945051063725834 já discutido
# 8.244334047856094 discutido anteriormente
# 7.956651975404314 única variável
# 6.251903883165888 biodegradada acumulada
# 6.45257457862804 razoável correlação
# 7.145721759187985 correlação linear
# 7.956651975404314 linear inversamente
# 7.397036187468891 inversamente proporcional
# 6.164892506176259 15 primeiros
# 7.145721759187985 primeiros dias
# 6.858039686736205 aparentemente mostrou-se
# 8.649799155964258 mostrou-se verdadeira
# 7.733508424090104 parece ter
# 6.634896135421995 mostram claramente
# 7.397036187468891 aprofundada desta
# 8.244334047856094 claramente governado
# 6.398507357357764 comportamento típico
# 6.1240705116560035 curva obtida
# 6.703889006908946 b representaria
# 6.398507357357764 possível prever
# 6.164892506176259 então reduzir
# 6.634896135421995 reduzir novamente
# 6.703889006908946 7 conclusões
# 7.551186867296149 aparentemente limitou-se
# 6.251903883165888 linear significativa
# 6.084849798502723 8 considerações
# 7.040361243530159 estudo seriam
# 9.342946336524204 seriam reduzidas
# 6.703889006908946 reduzidas caso
# 7.956651975404314 tivesse sido
# 7.263504794844368 sido avaliada
# 6.084849798502723 análises específicas
# 6.858039686736205 próximas pesquisas
# 8.649799155964258 regiões tropicais
# 9.342946336524204 referências nacionais
# 8.244334047856094 organização desse
# 8.244334047856094 desse conhecimento
# 6.570357614284423 serem aplicadas
# 7.551186867296149 devem preferencialmente
# 7.551186867296149 preferencialmente utilizar
# 8.244334047856094 futuras investigações
# 7.145721759187985 investigações sejam
# 6.858039686736205 sejam realizadas
# 6.570357614284423 parâmetros cinéticos
# 6.634896135421995 observados neste

# %%
# Função que recebe um sentença e o dicionário com MWE e retorna a sentença com os MWE unidos por "_". 

def uni_MWE(sent, mwe):
    
    mwe_tokenizer = MWETokenizer(list(mwe.keys()))
    sent = nltk.word_tokenize(sent)
    sent = mwe_tokenizer.tokenize(sent)
    sent = TreebankWordDetokenizer().detokenize(sent)
    return (sent)

# %% [markdown]
# Para cada arquivos do diretórios especificado lemos e preprocessamos o texto, unimos os bigrams considerados MWE, criamos uma rede de markov com os n-grams (state_size) e combinamos os modelos de todos os arquivos.

# %%
# Contador de tempo
start_time = time.time()

# Cadeia de Markov combinada
combined_model = None

# Contagem de arquivos
n_files = 0

# Iterar pelos diretórios e arquivos
for (dirpath, _, filenames) in os.walk("Originais/treino"):
    for filename in filenames:
        n_files += 1
        
        try:
            # Ler o arquivo e criar uma cadeia de Markov para cada arquivo
            with open(os.path.join(dirpath, filename), 'rb') as f:
                
                # Preprocessar o texto lido
                text = preprocess(f.read())
                text_mwe = []
                
                # Unir as MWE
                for sent in text:
                    text_mwe.append(uni_MWE(sent, mwe))
                
                # Treinar o modelos usando as o texto preprocessado e com MWE
                model = markovify.NewlineText(text_mwe, retain_original=False, state_size=2)

                # Combinar modelo criado para um arquivo com a Cadeia de Markov combinada
                if combined_model:
                    combined_model = markovify.combine(models=[combined_model, model])
                else:
                    combined_model = model
        except:
            print("Não foi possível ler o arquivo", filename)
            #pass
                    
        # Contador de arquivos processados
        if n_files % 50 == 0:
            print ("--- %s arquivos processados ---" % n_files, "--- %s seconds ---" % (time.time() - start_time))
    
# Fim do contador de tempo
print ("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 50 arquivos processados --- --- 321.5918276309967 seconds ---
# --- 100 arquivos processados --- --- 521.0643892288208 seconds ---
# --- 673.9112827777863 seconds ---

# %%
# Imprimir um exemplo de sentença aleatória
print(combined_model.make_sentence(max_words=50))
# Out:
#  exemplificando,  um inovador limite fixado pela regulamentação norueguesa diz respeito ao rendimento de sementes

# %%
# Gravar modelo em JSON em disco
model_json = combined_model.to_json()
with open('MarkovChainModel_mwe_MI6.json', 'w') as f:
    json.dump(model_json, f)

# %%
# Carregar modelo em JSON do disco
with open('MarkovChainModel_mwe_MI6.json', 'r') as f:
    model_json = markovify.Text.from_json(json.load(f))

# %% [markdown]
# Como os textos usados são em português, foi necessário codificar em 'ISO 8859-1', já o modelo JSON está codificado em UTF16. Portanto, ao ler e consultar os termos do modelo é necessário usar a codificação correta.

# %%
# Geração de sentença aleatória que iniciam com n-palavras

# Palavras que serãao usadas como semente
palavra_1 = 'a'
palavra_2 = 'petrobras'

# Ajustando a codificação para ser usado no modelo
palavra_1 = ' ' + palavra_1 + ' '
palavra_2 = ' ' + palavra_2
palavra_1 = palavra_1.encode('utf16')[3:]
palavra_2 = palavra_2.encode('utf16')[4:]
seed = palavra_1 + palavra_2

#Criando sentença aleatória iniciando com as palavras sementes
print(combined_model.make_sentence_with_start(seed.decode()))
# Out:
# a petrobras se enquadra

# %% [markdown]
# Do modelo criado pela biblioteca Markovify, extraímos a cadeia de Markov e gravamos em um dicionário

# %%
# Extrair cadeia de Markov do modelo
chain = combined_model.to_dict()['chain']
# Transformando a cadeia em um dicionário 
dic = {}
for state in json.loads(chain):
    dic[(state[0][0],state[0][1])] = state[1]

# %% [markdown]
# Criamos uma função para consultar a cadeia de Markov. Dado duas palavras, extraímos as próximas palavras possíveis, a contagem delas no conjunto de treinamento e a soma total. Dessa forma conseguimos calcular  $p(x_3|x_2,x_1)$.

# %%
# Função que dado duas palavras, retorna um dicionários com as probabilidades das palavras seguintes
def query_chain(palavra_1, palavra_2):
    # Selecionar o dicionário cuja entrada é o par de palavras "palavra_1" e "palavra_2"
    d = dic[(palavra_1, palavra_2)]
    new_d = {}
    # Transformar a contagem de palavras em probabilidade
    for w in d:
        new_d[w] = d[w]/sum(d.values())
    return (new_d)

# %% [markdown]
# O calculamos a perplexidade para cada sentença. Dada as primeiras palavras, obtivemos do modelo a probabilidade da palavra seguinte. Em seguida, avançamos pela sentença recuperando as probablidades.

# %%
# Dada uma sentença, a função retorna uma lista com as entropias calculada para cada trio de palavras
def entropy(sent):
    # Primeiro unimos os MWE
    sent = uni_MWE(sent, mwe)
    # Quebra a sentença em tokens
    words = nltk.word_tokenize(sent)
    # Variável para guardar a entropia de cada conjunto de palavras
    ln_prob_Xi = []
    # Janela de iteração pela sentença
    for w in range(len(words)-2):
        # Cálculo a entropia
        try:
            ln_prob_Xi.append(- math.log(query_chain(words[w], words[w+1])[words[w+2]]))
        except:
            pass

    return(np.mean(ln_prob_Xi))

# %%
# Função que recebe uma string com o caminho e nome da pasta com os arquivos e retorna a perplexidade

def perplexity(dirpath):

    # Início do contador de tempo
    start_time = time.time()
    
    # Variável para armazenar as entropias
    ent = []

    # Contagem de arquivos
    n_files = 0
    # Iterando pelos arquivos da pasta indicada em
    for (dirpath, _, filenames) in os.walk(dirpath):
        
        for filename in filenames:
            n_files += 1
            try:
                # Ler o arquivo e calcular a entropia
                with open(os.path.join(dirpath, filename), 'rb') as f:
                    # Preprocessar o texto lido
                    text = preprocess(f.read())
                    #Calcular a entropia da sentença
                    for sent in text:
                        ent.append(entropy(sent))

            except:
                print("Não foi possível ler o arquivo", filename)
        
                
            # Contador de arquivos processados
            if n_files % 5 == 0:
                print ("--- %s arquivos processados ---" % n_files, "--- %s seconds ---" % (time.time() - start_time))
    
    
    # Transformando a lista de entropias em uma np.array e excluir os valores "nan"
    ent = np.array(ent)
    ent = ent[~np.isnan(ent)]
    
    # Fim do contador de tempo
    print ("--- %s seconds ---" % (time.time() - start_time))
    
    return (math.exp(np.mean(ent)))

# %%
perplexity("Originais/teste")
# Out:
# C:\Users\upe2\AppData\Roaming\Python\Python36\site-packages\numpy\core\fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\upe2\AppData\Roaming\Python\Python36\site-packages\numpy\core\_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# --- 5 arquivos processados --- --- 91.36523985862732 seconds ---
# --- 10 arquivos processados --- --- 191.51184558868408 seconds ---
# --- 257.02381563186646 seconds ---
# 18.0179059425318
