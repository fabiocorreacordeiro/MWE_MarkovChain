# %% [markdown]
# ### Infêrência Estatística
# # Título: Avaliação do impacto da expressões multipalavras nos modelos de linguagem

# %% [markdown]
# Este script é similar ao caso base. Mas antes de criar o modelo de linguagem, identificamos as possíveis expressões multipalavras e substituímos a expressão por um único token.

# %%
import markovify
import os
import time
import json
import nltk
from nltk.probability import FreqDist
from nltk.tokenize import MWETokenizer
from nltk.tokenize.treebank import TreebankWordDetokenizer
import math
import numpy as np

# %% [markdown]
# Baseamos o código no Read me da biblioteca "Markovify" em: https://github.com/jsvine/markovify/blob/master/README.md

# %% [markdown]
# Primeiro criamos uma função para preprocessar o texto.

# %%
# Primeiro, criamos uma função para preprocessar os textos
def preprocess(text):
    # Decodificar usando ISO 8859-1 
    text = text.decode('ISO 8859-1')
    # Colocar todas as letras em minúscula
    text = text.lower()
    # Separar as sentenças pelos pontos de finais
    text = text.split('.')
    new_text = []
    for sent in text:
        # Eliminamos as sentenças com menos de 100 caracteres
        if len(sent)> 100:
            # Excluir os espaços no início e fim das sentenças
            new_text.append(sent.strip())
    return(new_text)

# %% [markdown]
# Unir os textos em um corpus único para identificar a frequência das palavras e dos bigrams

# %%
# Contador de tempo
start_time = time.time()

# Dicionário para armazenar a frequência da palavras
freq_words = {}
freq_bigram = {}

for (dirpath, _, filenames) in os.walk("Originais/treino"):
    for filename in filenames:

        
        # Ler o arquivo e recuperar a frequência das palavras e dos bibrams
        with open(os.path.join(dirpath, filename), 'rb') as f:
            # Preprocessar o texto lido
            text = preprocess(f.read())
            # Iterando por cada sentença
            for sent in text:
                # tokenizando as sentenças
                sent = nltk.word_tokenize(sent)
                # Recuperando a frequência das palavras da sentença
                freq = FreqDist(sent)
                # Atualizando o dicionário com frequência das palavras
                for i in freq:
                    try:
                        freq_words[i] = freq_words[i] + freq[i]
                    except:
                        freq_words[i] = freq[i]
                # Recuperando os bigram
                bigram = nltk.bigrams(sent)
                for i in bigram:
                    try:
                        freq_bigram[i] = freq_bigram[i] + 1
                    except:
                        freq_bigram[i] = 1      
                        
# Fim do contador de tempo
print ("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 48.863097190856934 seconds ---

# %% [markdown]
# Com a informação das frequências das palavras e dos bigram, é possível calcular a informação mútua.

# %%
# Calculando a Informação Mútua para cada bigram
bigram_MI = {}
n_bigram = len(freq_bigram)
n_word = len(freq_words)
for bi in freq_bigram:
    bigram_MI[bi] = math.log((freq_bigram[bi]/n_bigram)/
                             ((freq_words[bi[0]]/n_bigram)*(freq_words[bi[1]]/n_bigram)))

# %%
# Imprimindo o número total de palavras encontrado
sum(freq_words.values())
# Out:
# 3681623

# %%
# Imprimindo o número total de bigrams encontrado
print (len(bigram_MI))
# Out:
# 722623

# %% [markdown]
# Vamos considerar que um bigram é uma MWE aqueles pares de palavras cuja Informação Mútua ultrapassar um determinado limite.

# %%
# Criar uma lista de MWE com os bigrams que ultrapassem o limite assinalado na variável "MI".
mwe = {}
MI = 12.0
for bi in bigram_MI:
    if bigram_MI[bi] > MI:
        mwe[bi] = bigram_MI[bi]
print(len(mwe))
for e in mwe:
    print(bigram_MI[e], e[0], e[1])
# Out:
# 3852
# 12.79749574613375 poliamina cicloalifática
# 13.490642926693695 p'- dihidroxidifenildimetilmetano
# 12.392030638025586 scifider scholar
# 12.79749574613375 halogênio ehj
# 13.490642926693695 baton rouge
# 12.79749574613375 swing adsorption
# 13.490642926693695 tga/sdta 851e
# 12.392030638025586 tpd/tpr 2900
# 12.392030638025586 fundente lecocel
# 13.490642926693695 ts-ff -aas
# 12.79749574613375 boosted-discharge hollow
# 12.79749574613375 hollow cathode
# 12.79749574613375 ayame extraíram
# 13.490642926693695 6-dimetil -4-heptano
# 13.490642926693695 duolite gt-73
# 13.490642926693695 8-hydroxi quinolina
# 12.104348565573805 alitea c-6
# 12.79749574613375 hiperesfera eqüidistante
# 12.104348565573805 psa millennium
# 13.490642926693695 millennium excalibur
# 13.490642926693695 claind hg-2000
# 12.104348565573805 raypa scharlau
# 12.79749574613375 engine manufactures
# 12.79749574613375 ciclopentanos metilsubstituídos
# 12.79749574613375 4d3 5s2
# 13.490642926693695 h nb2o5
# 12.79749574613375 shin-ichi ito
# 12.79749574613375 ohkura tp2002s
# 12.392030638025586 phenomenex zb-1
# 12.392030638025586 phenomenex zb-5
# 12.392030638025586 espectroscópico transverso
# 12.104348565573805 relaxações rotovibracionais
# 13.490642926693695 heterocíclico tiofênico
# 12.104348565573805 22x10-3 moll-1
# 12.79749574613375 97x10-3 moll-1
# 12.392030638025586 inova 70c
# 13.490642926693695 melles griot
# 13.490642926693695 tds 5052
# 12.104348565573805 496 nm/525
# 13.490642926693695 udal tsov
# 13.490642926693695 70/110 71/110
# 13.490642926693695 71/110 72/110
# 13.490642926693695 72/110 73/110
# 12.79749574613375 desativações não-radiativas
# 12.79749574613375 mesoscópicas supramoleculares
# 13.490642926693695 quarteto mortal
# 12.104348565573805 dietas hipercalóricas
# 13.490642926693695 endocrinologista gerald
# 12.104348565573805 education program/adult
# 12.79749574613375 program/adult tratment
# 12.79749574613375 clinical endocrinologist
# 13.490642926693695 cardiopatia isquêmica
# 12.392030638025586 heart association/national
# 12.392030638025586 association/national heart
# 12.79749574613375 apolipoproteína c-iii
# 12.104348565573805 lipoproteína lípase
# 12.79749574613375 túbulo distal
# 13.490642926693695 arteríola aferente
# 12.104348565573805 renina angiotensina
# 12.104348565573805 angiotensina aldosterona
# 12.104348565573805 plasminogênio tecidual
# 12.392030638025586 sports medicine
# 12.104348565573805 inquérito domiciliar
# 12.104348565573805 sobrespeso/obesidade vivenciada
# 13.490642926693695 estudo/ população/
# 12.104348565573805 tortas salgadas
# 12.104348565573805 medicação anti-hipertensiva
# 12.104348565573805 compact logix
# 12.104348565573805 rockewll automation
# 13.490642926693695 bussiness ©
# 12.392030638025586 impossível esvaziar
# 13.490642926693695 programador concentre-se
# 12.79749574613375 ohkura tp2002
# 12.79749574613375 hv= 1254
# 12.392030638025586 escalab 200r
# 12.79749574613375 micro-ou mesoporosas
# 12.104348565573805 denominamos sabios
# 12.104348565573805 moduladas controlando-se
# 12.392030638025586 encadeiam tridimensionalmente
# 13.490642926693695 soccony mobil-5
# 12.392030638025586 heteropoliácidos neher
# 12.79749574613375 microe mesoporosas
# 12.104348565573805 spectrum bx-ii
# 12.392030638025586 chemsorb 2720
# 12.79749574613375 pulse chemisorption
# 12.392030638025586 chemsorb tpx
# 13.490642926693695 harrick praying
# 13.490642926693695 praying mantis
# 12.104348565573805 347 kjmol-1
# 12.392030638025586 octaedrico bo6
# 12.104348565573805 b o
# 13.490642926693695 metal citrato
# 12.79749574613375 ominstar qms
# 12.79749574613375 ominster qms
# 13.490642926693695 aminex hpx-87h
# 12.104348565573805 jcpd 33-0710
# 12.104348565573805 jcpd 84-1463
# 12.104348565573805 jcpd 17-0256
# 12.104348565573805 jcpd 82-1477
# 12.392030638025586 avicenia schaueriana
# 12.104348565573805 laguncularia racemosa
# 13.490642926693695 hibiscus tiliaceus
# 13.490642926693695 acrosticum aureum
# 13.490642926693695 ucides cordatus
# 13.490642926693695 uca thayeri
# 12.104348565573805 brotam pneumatóforos
# 12.79749574613375 tocas encobertas
# 13.490642926693695 zoe colocotronis
# 13.490642926693695 iso/cd 11348
# 12.79749574613375 tiborunella viscana
# 13.490642926693695 jenco eletronics
# 13.490642926693695 skeletonema costatum
# 13.490642926693695 medium-range weather
# 12.392030638025586 synthetic aperture
# 12.79749574613375 remote-sensing satellite
# 12.79749574613375 40°12 54
# 12.392030638025586 dir arctan
# 12.392030638025586 arctan sen
# 12.392030638025586 cdo delimitou-se
# 13.490642926693695 furacão mindulle
# 12.104348565573805 20°17 53
# 12.104348565573805 valdir innocentini
# 12.392030638025586 center/geodas databases
# 13.490642926693695 cubic spline
# 12.79749574613375 20°19 39
# 12.79749574613375 rotado 65°
# 12.79749574613375 anti-ciclone semi-estacionário
# 12.79749574613375 biweight 2=a
# 13.490642926693695 2=a 3=a
# 13.490642926693695 3=a 4=a
# 12.79749574613375 4=a 5=a
# 12.79749574613375 cm70 semidiurna
# 12.79749574613375 linux opensuse
# 13.490642926693695 compriment dao
# 13.490642926693695 k259 k496
# 13.490642926693695 k294 k636
# 12.104348565573805 °20 c°15
# 12.104348565573805 sarah valleta
# 12.79749574613375 w'' 40°
# 12.104348565573805 febre tifóide
# 13.490642926693695 disenteria amébica
# 12.104348565573805 10-37 kcal
# 12.79749574613375 timina timina
# 12.104348565573805 timina citosina
# 12.79749574613375 citosina citosina
# 12.104348565573805 toxicologistas subdividem
# 13.490642926693695 mysidium gracile
# 13.490642926693695 dodigen 1611
# 13.490642926693695 echinometra lucunter
# 13.490642926693695 seqües trante
# 12.392030638025586 corrosion coupons
# 13.490642926693695 atílio vivácqua
# 12.392030638025586 matas ciliares
# 12.79749574613375 convert raster
# 12.79749574613375 interpolate shape
# 12.392030638025586 zonal statistics
# 12.79749574613375 êù l
# 12.79749574613375 l aì
# 13.490642926693695 spirillum desulfuricans
# 12.79749574613375 mesófilos gram-negativos
# 12.392030638025586 5 -fosfosulfato
# 12.392030638025586 hidrogenase ni-fe
# 13.490642926693695 2780 mg/m³
# 12.79749574613375 air lift
# 12.104348565573805 40mg/l ogp
# 12.104348565573805 30mg/l ogp
# 13.490642926693695 fjord kysing
# 12.79749574613375 nmp/ 100ml
# 12.79749574613375 navio-tanque torrey
# 12.79749574613375 sinclair petrolore
# 13.490642926693695 t2ã²= lt1=±
# 12.79749574613375 =2 vu
# 12.104348565573805 0=z 0=z
# 13.490642926693695 zdu =dz
# 13.490642926693695 0=w 0=v
# 12.392030638025586 0=== 0=t
# 12.79749574613375 kga mmistura
# 12.79749574613375 5ø ß5øbü2
# 13.490642926693695 ß5øbü2 5øcü2
# 12.79749574613375 6th iwa
# 12.79749574613375 nsw 2052
# 12.79749574613375 australia *corresponding
# 13.490642926693695 *corresponding author
# 12.392030638025586 nearby residents
# 12.79749574613375 correctly estimated
# 12.79749574613375 diameter wrapped
# 13.490642926693695 perforations equidistantly
# 13.490642926693695 equidistantly spaced
# 13.490642926693695 schematic drawing
# 12.79749574613375 well-known kð-µ
# 13.490642926693695 adequately refined
# 12.392030638025586 recommends waiting
# 12.79749574613375 nearly unperceivable
# 12.392030638025586 motion transports
# 12.104348565573805 two-equation eddy-viscosity
# 12.79749574613375 1598 1605
# 12.104348565573805 aiaa 24th
# 12.104348565573805 24th aerospace
# 13.490642926693695 disturbance noted
# 12.79749574613375 recurring demand
# 12.79749574613375 intensive livestock
# 12.392030638025586 oxidized chemically
# 12.104348565573805 later stage
# 12.392030638025586 creates eddies
# 12.392030638025586 commonly classified
# 12.79749574613375 match typical
# 13.490642926693695 non-uniform non-structured
# 12.79749574613375 million nodes
# 12.79749574613375 5ønü15øxü 5øß5øaü
# 12.392030638025586 strict mathematical
# 12.392030638025586 closure coefficients
# 12.104348565573805 scheme unconditionally
# 12.79749574613375 cfx-solver computes
# 12.79749574613375 connecting meshes
# 12.104348565573805 dissimilar meshes
# 12.79749574613375 worth noting
# 12.392030638025586 considerably reduced
# 12.104348565573805 minor difference
# 12.392030638025586 strongly affected
# 13.490642926693695 directly proportional
# 12.79749574613375 already considerable
# 12.79749574613375 air water
# 12.79749574613375 sheared gas
# 12.79749574613375 gas liquid
# 12.392030638025586 predicts air-water
# 12.392030638025586 paraffin wax
# 12.392030638025586 wax appearence
# 12.79749574613375 laser-induced acoustic
# 12.79749574613375 isoctano abstraindo
# 12.79749574613375 ++ 2ei
# 12.79749574613375 modulador zx1-gc
# 13.490642926693695 sigma aldrich
# 12.79749574613375 physica mcr-301
# 12.79749574613375 modulador zx1-gc×gc
# 13.490642926693695 ingês collision-induced
# 12.79749574613375 w1 w3
# 12.79749574613375 tetra-e penta-cíclicos
# 12.392030638025586 520 560
# 12.79749574613375 504 509
# 13.490642926693695 505 507
# 12.104348565573805 13c1 12c35h74-h
# 12.392030638025586 13c2 12c34h74-h
# 13.490642926693695 369 375
# 12.104348565573805 13c1 12c26h48
# 12.392030638025586 13c2 12c25h48
# 12.104348565573805 13c1 12c26h48-h
# 12.392030638025586 13c2 12c25h48-h
# 13.490642926693695 13c3 12c24h48-h
# 13.490642926693695 371 374
# 13.490642926693695 544 547
# 12.392030638025586 12c22 13c2h12
# 12.104348565573805 12c23 13c1h12+h
# 12.104348565573805 12c17 13c1h12
# 12.392030638025586 12c16 13c2h12
# 12.104348565573805 13c1 12c17h12
# 12.79749574613375 450 1200
# 12.392030638025586 unicelulares microscópicos
# 12.79749574613375 acácia mearnsii
# 13.490642926693695 schizochytrium limacinum
# 12.79749574613375 empregaram-se duplicações
# 12.392030638025586 famosos jardins
# 12.104348565573805 romanos aplicaram-no
# 12.104348565573805 baku fluía
# 13.490642926693695 np 2266
# 13.490642926693695 perfuradores pensarem
# 12.392030638025586 ba2+e sr2+
# 13.490642926693695 metpac cc-1
# 13.490642926693695 toyopearl af-chelate-650m
# 13.490642926693695 chitopearl ci-03
# 12.392030638025586 interelementares experimentadas
# 12.392030638025586 elipsoidais focalizadores
# 13.490642926693695 double-echelle monochromator
# 12.392030638025586 pássaros piscívoros
# 13.490642926693695 gadus morhua
# 12.392030638025586 platichthys flesus
# 13.490642926693695 curvier 1829
# 13.490642926693695 hepatose megalocítica
# 12.392030638025586 meridianos 043°00
# 13.490642926693695 22°54 6
# 13.490642926693695 23°04 18
# 12.392030638025586 meridianos 43°33
# 13.490642926693695 43°33 42
# 13.490642926693695 44°02 30
# 12.79749574613375 44o 40
# 12.79749574613375 bombonas aeradas
# 13.490642926693695 alt hist*=
# 12.104348565573805 a750h/ a750l
# 12.79749574613375 ultra-centrífuga refrigerada
# 13.490642926693695 himac cr21gii
# 13.490642926693695 ex/em 550/582
# 12.104348565573805 anatomia patológica
# 12.392030638025586 ademoma hepatocelular
# 13.490642926693695 fmol/10 fmol/5
# 13.490642926693695 fmol/5 fmol/2
# 13.490642926693695 fosfatase avidina-alcalina
# 13.490642926693695 cpd-star úö
# 13.490642926693695 wallac 1420
# 12.104348565573805 totalizaram 991
# 12.104348565573805 geert hofstede
# 12.104348565573805 betânia tanure
# 12.79749574613375 abraham maslow
# 13.490642926693695 discente cursa
# 12.79749574613375 alfie kohn
# 12.104348565573805 ajudarem-se mutuamente
# 12.104348565573805 exemplar arregimenta
# 13.490642926693695 entendimento comum
# 12.392030638025586 mal-entendido recíproco
# 13.490642926693695 sidney jourard
# 13.490642926693695 alvin toffler
# 12.104348565573805 experiential education
# 13.490642926693695 atividade lúdica
# 12.79749574613375 corporate adventure
# 12.79749574613375 adventure training
# 13.490642926693695 cabra cega
# 12.104348565573805 experimentem sensações
# 12.392030638025586 envolve-se cotidianamente
# 12.79749574613375 colete salva-vidas
# 12.104348565573805 leadership practices
# 12.104348565573805 pontuações oscilaram
# 12.79749574613375 directive 2001/81/ce
# 12.104348565573805 capa fechando
# 12.79749574613375 -radial plume
# 13.490642926693695 bernie steigerwald
# 13.490642926693695 nta 8399
# 13.490642926693695 directiva 96/61/eu
# 12.79749574613375 subpart ggg
# 12.104348565573805 enforcement alert
# 12.79749574613375 backscatter absortion
# 13.490642926693695 multi-spectral sensing
# 13.490642926693695 aline voigt
# 13.490642926693695 voigt naldoni
# 13.490642926693695 valéria póvoa
# 13.490642926693695 hermogerio schmall
# 12.392030638025586 vaques feldspáticas
# 13.490642926693695 986923 um2
# 12.104348565573805 microtomógrafo skyscan
# 12.392030638025586 crab orchad
# 12.392030638025586 boise idaho
# 12.392030638025586 oise idaho
# 13.490642926693695 pulverisette fritsch
# 12.104348565573805 -15 x10-6
# 13.490642926693695 princ ípio
# 13.490642926693695 conseque ntemente
# 12.104348565573805 mp= miniplugue
# 12.104348565573805 soft ware
# 12.392030638025586 non-local-means filter
# 12.79749574613375 axis conectivity
# 12.392030638025586 d8 advance
# 13.490642926693695 axio scope
# 12.392030638025586 zircão englobados
# 13.490642926693695 al6 si30
# 13.490642926693695 si30 o72
# 12.392030638025586 cutículas lamelosas
# 12.79749574613375 fotomic rografia
# 13.490642926693695 cutíc ulas
# 12.104348565573805 empacot amento
# 13.490642926693695 pont uais
# 12.79749574613375 calc ítica
# 13.490642926693695 fot omicrografia
# 12.79749574613375 felds patos
# 12.392030638025586 az ul
# 13.490642926693695 porc entagem
# 12.79749574613375 entagem ent
# 12.79749574613375 244140 ¼m³
# 13.490642926693695 mikhael semenovich
# 13.490642926693695 semenovich tswett
# 13.490642926693695 conficgurações radia
# 13.490642926693695 riedel-de haën
# 12.104348565573805 acros organics
# 12.79749574613375 icap 6300
# 13.490642926693695 branson 1510
# 12.79749574613375 50w x8
# 12.104348565573805 lewatit s100
# 12.392030638025586 mili equivalentes-grama
# 12.104348565573805 amberlit irc
# 12.392030638025586 competence baseline
# 12.392030638025586 competency baseline
# 13.490642926693695 classificação/priorização multicritério
# 12.392030638025586 produção puxada
# 12.104348565573805 lump sum
# 12.392030638025586 unit-rate contract
# 13.490642926693695 pesquisa ação
# 12.392030638025586 criteriosamente recrutado
# 12.104348565573805 tentava abri-lo
# 12.104348565573805 exclamações amarelas
# 12.79749574613375 seladoras sobrejacentes
# 13.490642926693695 22°40' 23°00's
# 13.490642926693695 43°00' 43°18'o
# 12.79749574613375 subfundo syqwest
# 13.490642926693695 bathy 2010pc
# 12.79749574613375 hidrográfico hypack®
# 13.490642926693695 dgps techgeo
# 12.79749574613375 multisensores multi-sensor
# 12.392030638025586 rolha butílica
# 12.79749574613375 porapak qs
# 13.490642926693695 graphpad prism
# 12.104348565573805 sed úmido-1
# 12.392030638025586 moral hazard
# 12.104348565573805 radicalização político-ideológica
# 12.104348565573805 político-ideológica fomentada
# 13.490642926693695 depositary receipts
# 13.490642926693695 bengt hakon
# 13.490642926693695 hakon hallqvist
# 12.79749574613375 sueco naturalizado
# 12.392030638025586 best pratices
# 13.490642926693695 solidamente enraizados
# 12.79749574613375 reordenamento jurídico-institucional
# 12.392030638025586 filtros interpretativos
# 12.104348565573805 golfinho rotador
# 13.490642926693695 líquida ebitda
# 12.79749574613375 2015 2019
# 13.490642926693695 due diligence
# 12.79749574613375 adalberto elek
# 12.79749574613375 ministra aposentada
# 13.490642926693695 ellen gracie
# 12.79749574613375 andreas pohlmann
# 13.490642926693695 gesetz über
# 12.79749574613375 über die
# 12.79749574613375 die mitbestimmung
# 13.490642926693695 ii-serão convocadas
# 12.392030638025586 dellamora bonolo
# 12.104348565573805 precisamos virar
# 12.79749574613375 papai noel
# 12.392030638025586 estou cansado
# 13.490642926693695 cargo/função comissionada
# 12.104348565573805 seria oportuno
# 13.490642926693695 aportar olhares
# 12.79749574613375 muitos criticam
# 12.79749574613375 substantial economies
# 12.79749574613375 ceteris paribus
# 12.392030638025586 traditional input/output
# 12.104348565573805 maintain considerable
# 13.490642926693695 mão de-obra
# 13.490642926693695 describe sectoral
# 13.490642926693695 sectoral dependences
# 13.490642926693695 índice20 tornaram-no
# 12.104348565573805 cidade-capital evoluísse
# 12.79749574613375 crips sets
# 12.79749574613375 uik 1-agropecuária
# 13.490642926693695 1-agropecuária 16-fabricação
# 12.392030638025586 não-petroquímicos 29-fabricação
# 12.79749574613375 mobiliário 25-beneficiamento
# 12.392030638025586 peles 21-indústria
# 13.490642926693695 hirschaman rasmussen
# 13.490642926693695 isoenzima fosfodiesterase
# 13.490642926693695 pré clínicos
# 13.490642926693695 ergogenia medicamentosa
# 13.490642926693695 bombe chimiche
# 12.79749574613375 medical comission
# 12.79749574613375 mitologia nórdica
# 12.392030638025586 latinos mascavam
# 12.79749574613375 linton faleceu
# 13.490642926693695 vôos noturnos
# 12.79749574613375 jogadores-soldados retornaram
# 12.79749574613375 knut enemark
# 12.79749574613375 vasodilatador coronariano
# 12.392030638025586 dirck howard
# 12.79749574613375 tommy simpson
# 12.104348565573805 simpson faleceu
# 12.104348565573805 esqui vôlei
# 12.104348565573805 vôlei ciclismo
# 12.79749574613375 ciclismo ginástica
# 12.104348565573805 pentatlon natação
# 12.79749574613375 diuréticos beta-2
# 12.104348565573805 antagonistas betabloqueadores
# 12.79749574613375 secreções gástricas
# 12.79749574613375 descongestionantes nasais
# 12.79749574613375 arritmias cardíacas
# 12.104348565573805 humor vítreo
# 12.79749574613375 inalante vick®
# 13.490642926693695 accubondii ods-c18
# 12.79749574613375 dimetapp gelcápsula
# 12.392030638025586 scifinder scholar
# 12.104348565573805 estudante allan
# 13.490642926693695 áreaanalito/ áreapadrão
# 12.392030638025586 psicólogo neivaldo
# 12.392030638025586 psicodiagnóstico miocinético
# 12.392030638025586 musculares involuntárias
# 13.490642926693695 supermartensitic stainless
# 12.79749574613375 stainless steel
# 12.392030638025586 carboneto cr23c6
# 12.79749574613375 pitting resistence
# 12.392030638025586 circunferêncial multipasse
# 12.79749574613375 jsm 35c
# 13.490642926693695 voyager 3050
# 13.490642926693695 girth welds
# 12.104348565573805 multi-processo sinérgica
# 12.392030638025586 esab aristopower
# 13.490642926693695 aristopedant u8
# 12.392030638025586 esab ok
# 12.79749574613375 ok tigrod
# 12.79749574613375 tigrod 2509
# 12.79749574613375 flux cored
# 12.79749574613375 ok tubrod
# 12.392030638025586 dðt 8/5
# 12.79749574613375 micografia optica
# 13.490642926693695 martensita fresh
# 13.490642926693695 gear lubricant
# 12.104348565573805 ohlð+ ch3oh
# 13.490642926693695 393 366
# 12.392030638025586 sgs geosol
# 12.392030638025586 nonilfenol etoxilado
# 13.490642926693695 octodecyl silane
# 12.392030638025586 silane chemically
# 12.392030638025586 chemically bonded
# 12.79749574613375 printex u-degussa
# 12.392030638025586 valências +ii
# 12.104348565573805 4f1 5d1
# 13.490642926693695 antiligante à*g
# 13.490642926693695 anti-ligantes à*
# 13.490642926693695 bio-polímero quitosana
# 12.392030638025586 ethylenidiamine c2h4
# 12.79749574613375 wilhelm conrad
# 13.490642926693695 conrad röntgen
# 12.392030638025586 policristais rigaku
# 13.490642926693695 geigerflex 2037
# 13.490642926693695 10-34 j·s
# 12.79749574613375 ²= e'/2me=
# 12.392030638025586 10-24 am2
# 13.490642926693695 0546 x10
# 13.490642926693695 zero-field splitting
# 12.79749574613375 gzze axx
# 13.490642926693695 1858 1913
# 12.79749574613375 elaeis guineensis
# 12.79749574613375 elaeis guinnensis
# 13.490642926693695 biodiesel-perfil nacional-referência
# 12.104348565573805 pâncreas suína
# 12.104348565573805 monoésteres alquilícos
# 13.490642926693695 fabricando magnetrons
# 13.490642926693695 µ´´/ µ´
# 12.79749574613375 panasonic nn-modelo
# 13.490642926693695 nn-modelo píccolo
# 13.490642926693695 píccolo s42bk
# 13.490642926693695 middi cms
# 13.490642926693695 cms 30ab
# 12.392030638025586 adolfo lutz
# 12.392030638025586 magnetic stirrer
# 12.79749574613375 adventurer ohaus
# 12.392030638025586 fenomeno fisico
# 12.392030638025586 fenomeno quimico
# 13.490642926693695 quimico atibuida
# 13.490642926693695 reções quimicas
# 12.392030638025586 leonel cancico
# 12.392030638025586 reflectido 1222
# 12.104348565573805 n-propilcyclohexano diluido
# 12.104348565573805 overdriven detonation
# 12.104348565573805 eigenvalue detonation
# 12.104348565573805 hipérbole equilátera
# 12.104348565573805 spinning detonation
# 12.104348565573805 codex alimentarius
# 12.104348565573805 3078 ng/dia
# 12.104348565573805 cárneos defumados
# 12.79749574613375 coffea canephora
# 13.490642926693695 kg/por habitante/ano
# 12.104348565573805 cereja descascados
# 12.79749574613375 iso/iec 17025
# 13.490642926693695 biotage turbovap
# 13.490642926693695 multivapor-p6 buchi
# 12.104348565573805 micropipetas eppendorf
# 13.490642926693695 chester thoradson
# 12.104348565573805 norweb communications
# 12.79749574613375 digital powerline
# 12.79749574613375 low-voltage electrical
# 12.79749574613375 electrical installations
# 13.490642926693695 general requirement
# 13.490642926693695 electromagnetic disturbances
# 12.104348565573805 modularidade ûca
# 13.490642926693695 orthogonal frequency-division
# 13.490642926693695 frequency-division multiplexing
# 12.79749574613375 demodulador tome
# 12.392030638025586 signiûca quadrature
# 12.392030638025586 quadrature phase-shift
# 12.392030638025586 eight phase-shift
# 13.490642926693695 électricité réseau
# 12.104348565573805 pulse width
# 12.79749574613375 width modulation
# 12.104348565573805 third-harmonic injection
# 12.392030638025586 gráûco powergui
# 12.104348565573805 arduíno mega
# 12.79749574613375 ûexível unipolar
# 13.490642926693695 codiûcação xmodem
# 13.490642926693695 inversor/motor ûque
# 12.392030638025586 mozambique aluminium
# 12.392030638025586 sasol lta
# 12.392030638025586 clóvis ático
# 12.104348565573805 missiones bolivarianas
# 13.490642926693695 kimberlito camafuca
# 12.392030638025586 sena sugar
# 12.79749574613375 megaprojeto mozambique
# 13.490642926693695 europa eurásia
# 12.104348565573805 mineradora australiana
# 12.392030638025586 calcários metamórficos
# 12.79749574613375 pegmatitos graníticos
# 13.490642926693695 liquor negro1
# 13.490642926693695 decênio 2012-2021
# 12.104348565573805 bagas fazem-se
# 13.490642926693695 historiorum mundi
# 13.490642926693695 xuzhou orient
# 12.392030638025586 granulares polidispersas
# 12.79749574613375 bomb combustion/ion
# 13.490642926693695 ë *ì
# 13.490642926693695 *ì 1í
# 12.79749574613375 g a
# 13.490642926693695 r ém
# 12.79749574613375 s q
# 12.392030638025586 q r
# 12.392030638025586 r t
# 13.490642926693695 cetil trimetilamônio
# 12.79749574613375 iê ñ
# 12.392030638025586 posa manusear
# 13.490642926693695 npt 8210
# 12.79749574613375 dataloggers mypclab
# 12.79749574613375 7 *6
# 12.79749574613375 *6 5
# 13.490642926693695 5 15
# 12.104348565573805 15 4
# 12.104348565573805 4 17
# 13.490642926693695 a 5pq
# 12.79749574613375 gamma-ray tomograph
# 12.392030638025586 guilherme estrella
# 12.392030638025586 nós pesquisamos
# 12.104348565573805 geometric coherence
# 13.490642926693695 computed tomography
# 13.490642926693695 filtered back-projection
# 12.392030638025586 johann heinrich
# 12.392030638025586 posto-linha cheio
# 12.79749574613375 tomográficas computadorizadas
# 12.79749574613375 21 22
# 12.104348565573805 stefan kaczmarz
# 13.490642926693695 angentihrte auflosung
# 13.490642926693695 systemen linearer
# 13.490642926693695 linearer gleichunen
# 12.392030638025586 solomon kullback
# 12.104348565573805 hirotugu akaike
# 12.392030638025586 dickey fuller
# 12.392030638025586 rfa outlook
# 12.79749574613375 dea+ deh
# 12.104348565573805 arch m
# 12.104348565573805 estimações bayesianas
# 12.79749574613375 afrescos decorativos
# 12.104348565573805 theofraste citou
# 13.490642926693695 sarcófagos decorados
# 13.490642926693695 lavoisier presenteou
# 12.104348565573805 monoclínicos prismáticos
# 12.104348565573805 gessos aditivados
# 12.104348565573805 supercalcinada caso4
# 12.392030638025586 cµ2 c¼1
# 13.490642926693695 dall agnol
# 12.104348565573805 lw =1
# 12.79749574613375 constante c2e
# 12.79749574613375 stefan bolztmann
# 12.392030638025586 sst-eddy dissipation-roseland
# 12.104348565573805 naturally replenishing
# 13.490642926693695 virtually inexhaustible
# 12.392030638025586 made again
# 12.392030638025586 short period
# 12.79749574613375 717516 10³
# 12.79749574613375 1296273 10³
# 12.79749574613375 1970/80 privilegiaram
# 13.490642926693695 pde 2007/2016
# 13.490642926693695 ney aminthas
# 12.392030638025586 jirau ampliará
# 13.490642926693695 wobben windpower
# 13.490642926693695 ecodiesel b-20
# 13.490642926693695 diversificadade seusácidos
# 12.79749574613375 agradáveis sensorialmente
# 13.490642926693695 daassociação brasileiradas
# 13.490642926693695 libror eb-330h
# 12.392030638025586 deixando-se refluxar
# 13.490642926693695 11º estagio
# 12.79749574613375 tray sizing
# 12.79749574613375 tray rating
# 12.104348565573805 m/s2
# 12.392030638025586 comofluidização agregativa
# 12.392030638025586 umb= umf
# 12.392030638025586 movendo àmesma
# 12.104348565573805 bombeiro interliga
# 13.490642926693695 apresentadono apêndiceb
# 12.104348565573805 subscritos fg
# 13.490642926693695 raios-gðde am-241
# 12.79749574613375 computationalfluid dynamics
# 12.104348565573805 duas equações
# 12.104348565573805 602 kg/m2/s
# 12.79749574613375 k-e -bases
# 13.490642926693695 razãoentre avelocidade
# 13.490642926693695 importantenadeterminação dotempo
# 13.490642926693695 residênciade reacçõese
# 12.104348565573805 y2 ey3
# 13.490642926693695 situamos socioeconomicamente
# 13.490642926693695 preferirem denominá-las
# 13.490642926693695 abade guettard
# 12.79749574613375 iná elias
# 12.79749574613375 ça sert
# 13.490642926693695 jean-paul ferrier
# 12.104348565573805 mais inteligível
# 12.104348565573805 associativos reticulados
# 13.490642926693695 baianas volvidas
# 12.104348565573805 enclave desterritorializado
# 13.490642926693695 guy debord
# 12.392030638025586 estiagens matavam
# 13.490642926693695 algodoais aproveitavam
# 12.79749574613375 tinha-se enxergado
# 13.490642926693695 bacaiúva catão
# 13.490642926693695 associava paternalismo
# 12.104348565573805 tornava-se antieconômico
# 12.104348565573805 algodoal mocó
# 12.392030638025586 cotonicultores norte-rio-grandenses
# 13.490642926693695 ímpetos integracionistas
# 12.104348565573805 decreto-lei 1428/75
# 12.79749574613375 sparta nordeste*
# 13.490642926693695 soriedem* incarton*
# 13.490642926693695 incarton* sperb
# 13.490642926693695 anthonomus grandis
# 13.490642926693695 grandis boheman
# 12.392030638025586 várzeas irrigáveis
# 12.392030638025586 tenente ananias
# 12.104348565573805 regionalmente desequilibrado
# 12.79749574613375 58 63
# 12.79749574613375 exuberante pasto
# 12.79749574613375 hectare/ano impressionava
# 12.79749574613375 casper branner
# 13.490642926693695 oil possibiliteis
# 13.490642926693695 róiti deixei
# 12.79749574613375 cidade/região assenta
# 12.392030638025586 ifrn-mossoró jailton
# 13.490642926693695 lugares po-voados
# 12.392030638025586 euvaldo lodi
# 12.104348565573805 473 toneladas32
# 12.79749574613375 desmatamentos autorizados
# 12.392030638025586 impresso publicitário
# 12.79749574613375 annona cherimola
# 12.79749574613375 annona squamosa
# 13.490642926693695 agrônoma extenisonista
# 12.104348565573805 refeitório pros
# 12.104348565573805 dona isaura
# 13.490642926693695 francisca balbina
# 12.104348565573805 balbina neta
# 13.490642926693695 bb bi
# 12.79749574613375 transmissoras itapebi
# 12.104348565573805 françois villon
# 12.392030638025586 alto-rodriguense vislumbrou
# 12.104348565573805 vereador nixon
# 12.79749574613375 vereador reeleito
# 13.490642926693695 hóspedes pegou
# 12.104348565573805 elbert smient
# 13.490642926693695 jandir candéas
# 12.104348565573805 sopra ordinariamente
# 13.490642926693695 adriano verdonck
# 12.392030638025586 peticionários justificavam
# 12.104348565573805 joana cavalcante
# 12.392030638025586 meus tios
# 13.490642926693695 tropeiros carregavam
# 12.392030638025586 werner jost
# 12.104348565573805 brava dedica-se
# 13.490642926693695 despesca matam
# 13.490642926693695 adecio filho-sec
# 13.490642926693695 benedito otone
# 13.490642926693695 abraão junior-superintendente
# 12.79749574613375 lucas galdena-sub
# 12.392030638025586 tre-rn acolheu
# 13.490642926693695 sandra mary
# 13.490642926693695 iddepoe ntehome=16906
# 12.392030638025586 politica assistencialista
# 12.79749574613375 confundem 'generosidade'
# 13.490642926693695 barcaça transportava
# 12.392030638025586 museu lauro
# 12.392030638025586 mos-66 koster
# 12.392030638025586 alfândega provincial
# 12.79749574613375 suíço johan
# 13.490642926693695 johan ulrich
# 12.104348565573805 empórios nordestinos
# 12.79749574613375 fortunas desapareceram
# 12.104348565573805 esam 68-
# 13.490642926693695 devamos coloca-la
# 12.79749574613375 messias targino
# 13.490642926693695 alardeavam apocalipticamente
# 12.392030638025586 nas/das várzeas
# 12.392030638025586 entrevistada referenciaram
# 12.104348565573805 realize partos
# 12.104348565573805 moto taxi
# 12.79749574613375 solicitam carona
# 12.104348565573805 faz-nos lembrarmos
# 12.104348565573805 strong exothermic
# 13.490642926693695 exothermic nitrations
# 12.104348565573805 ni-al2o3 interactions
# 12.79749574613375 liquid-liquid two-phase
# 13.490642926693695 threonine aldolase
# 13.490642926693695 aldolase immobilization
# 12.392030638025586 explosive mixture
# 12.79749574613375 microstructured reactor/heat
# 12.79749574613375 reactor/heat exchanger
# 12.104348565573805 efficient ni/ceo2/al2o3
# 12.104348565573805 cerium oxides
# 12.392030638025586 soda-lime glass
# 12.392030638025586 actuators b-chemical
# 12.79749574613375 non-conventional microfabrication
# 12.392030638025586 simpósio ibero-americano
# 13.490642926693695 polimorfos boehmita
# 12.104348565573805 að-al2o3 conferiam-lhe
# 13.490642926693695 catalític peraturas
# 13.490642926693695 heterog aixo
# 12.392030638025586 modu ado
# 12.79749574613375 deta misturad
# 12.79749574613375 erentes reato
# 12.79749574613375 reato knitter
# 12.79749574613375 lia alítico
# 13.490642926693695 alítico heter
# 13.490642926693695 heter orreator
# 12.79749574613375 orreator cata
# 12.79749574613375 ores cerâmi
# 13.490642926693695 elemen veis
# 12.79749574613375 esqu crocanais
# 12.79749574613375 removí fase-gasosa
# 12.104348565573805 nais removí
# 12.79749574613375 removí ntos
# 13.490642926693695 ntos funcion
# 13.490642926693695 funcion uerda
# 13.490642926693695 autotérmic aproximad
# 12.392030638025586 iso-oc damente
# 12.392030638025586 mitadas pel
# 12.392030638025586 pel ctano
# 13.490642926693695 ndo-se exce
# 13.490642926693695 elente desem
# 13.490642926693695 velocida esenvolvido
# 13.490642926693695 esenvolvido stado
# 13.490642926693695 ades espacia
# 13.490642926693695 mét orreatores
# 13.490642926693695 térmi uras
# 13.490642926693695 anód entado
# 13.490642926693695 alu ganley
# 13.490642926693695 morfol umina
# 13.490642926693695 icrorreatore artir
# 13.490642926693695 cerâm omposição
# 13.490642926693695 micror nsidade
# 13.490642926693695 microca micromanufa
# 12.392030638025586 ando divers
# 13.490642926693695 co-re/gð-mbém recobe
# 13.490642926693695 recobe culares
# 13.490642926693695 culares tamb
# 13.490642926693695 tamb ncia
# 13.490642926693695 superfíci etro
# 13.490642926693695 micromonó ólito
# 13.490642926693695 rfície dispon
# 13.490642926693695 recob oscopia
# 13.490642926693695 oscopia elet
# 13.490642926693695 mostr trutura
# 12.104348565573805 ento catalít
# 13.490642926693695 reco font
# 13.490642926693695 analar normapur
# 12.79749574613375 heraeus m110
# 12.79749574613375 heraeus thermicon
# 13.490642926693695 nabertherm controller
# 13.490642926693695 controller p320
# 13.490642926693695 marca/modelo lindberg/blue
# 12.104348565573805 syringe drive
# 12.392030638025586 incipient wetness
# 13.490642926693695 ogravimetri proximaria
# 12.79749574613375 proximaria ise
# 12.79749574613375 264ºc refe
# 13.490642926693695 hex mprovaram
# 13.490642926693695 análi segun
# 12.79749574613375 grafos anter
# 13.490642926693695 pré-cat riores
# 12.104348565573805 céri -se
# 12.79749574613375 parág izada
# 12.79749574613375 progr ores
# 12.79749574613375 figur tempe
# 12.79749574613375 tempe catali
# 12.104348565573805 catali catali
# 13.490642926693695 iversas prop
# 12.104348565573805 pré-catalisadores23 moídos
# 12.392030638025586 planetary ball
# 12.392030638025586 ball mill
# 12.392030638025586 zetasizer nano
# 12.392030638025586 hitachi s2700
# 12.104348565573805 perovskite-type oxides
# 12.392030638025586 massively parallel
# 12.392030638025586 parallel microfluidic
# 12.79749574613375 didactic experiment
# 12.79749574613375 nimo/al2o3 hydrotreating
# 12.79749574613375 mechanically agitated
# 12.79749574613375 preferential oxidation-heat
# 12.79749574613375 oxidation-heat exchanger
# 12.79749574613375 exchanger microdevice
# 13.490642926693695 nitrate hexahydrate
# 13.490642926693695 coke-and sintering-resistant
# 12.104348565573805 sintering-resistant monolithic
# 12.79749574613375 hydrotalcite-like films
# 13.490642926693695 nio/zro2 calcined
# 12.104348565573805 nanostructured ni/ceo2
# 12.79749574613375 microstructure compatible
# 12.104348565573805 trac trends
# 13.490642926693695 tungstosilicic acid-supported
# 13.490642926693695 static mixers
# 12.79749574613375 heterogeneously catalysed
# 13.490642926693695 n-alkylimidazolium ionic
# 13.490642926693695 9-substituted anthracenes
# 12.392030638025586 temperature-programmed surface-reaction
# 12.79749574613375 acid base
# 13.490642926693695 vibrationally excited
# 12.392030638025586 microreactor-based parallel
# 12.104348565573805 looping pilot
# 12.79749574613375 ifp energies
# 13.490642926693695 energies nouvelles
# 12.392030638025586 nio-al2o3-tio2 hydrogenation
# 12.104348565573805 ni/al2o3-zro2 xerogel
# 13.490642926693695 non-noble nanocatalysts
# 12.392030638025586 sulphur tolerance
# 12.79749574613375 oxide slurries
# 13.490642926693695 epoxide aminolysis
# 13.490642926693695 knoevenagel condensation
# 12.104348565573805 conventional nickel-based
# 13.490642926693695 adim nal
# 13.490642926693695 condi eais
# 12.392030638025586 qu onização
# 13.490642926693695 cromatogr rama
# 12.79749574613375 apresent tado
# 12.79749574613375 nbs tables
# 12.79749574613375 c-2 organic-substances
# 13.490642926693695 haldor topsøe
# 12.104348565573805 detergent-range oxo
# 13.490642926693695 kohle erdgas
# 13.490642926693695 erdgas petrochemie
# 12.392030638025586 fossil fired
# 12.79749574613375 nanocrystalline mgal2o4
# 12.79749574613375 hot coke
# 12.79749574613375 coke oven
# 12.392030638025586 simpósio iberoamericano
# 13.490642926693695 verd dondamento
# 13.490642926693695 conside consideraçã
# 13.490642926693695 rculares pró
# 13.490642926693695 oderia eventua
# 13.490642926693695 almente propic
# 12.79749574613375 +ð ð
# 12.104348565573805 finamente granulados
# 12.79749574613375 thiele 1fð=ð
# 12.79749574613375 shape normalization
# 13.490642926693695 space-time cese
# 13.490642926693695 reforming-combustion coupling
# 12.104348565573805 subgrid embedded
# 12.104348565573805 embedded finite-element
# 12.104348565573805 finite-element basis
# 13.490642926693695 réaction chimique
# 12.79749574613375 fonctionement dês
# 12.79749574613375 dês réacteurs
# 12.79749574613375 multichannel microcirculating
# 12.392030638025586 sugerindo-se elevar-se
# 13.490642926693695 galactic nuclei
# 12.392030638025586 mrk 1066
# 12.79749574613375 multi-object spectrograph
# 13.490642926693695 monthly notices
# 13.490642926693695 547m/f 791w
# 12.104348565573805 inclinado 56æ
# 12.79749574613375 weaver gelbord
# 12.392030638025586 astronômicas iraf
# 12.392030638025586 template mismatch
# 12.392030638025586 orbitas keplerianas
# 12.79749574613375 unsharp mask
# 12.104348565573805 desenhamos isovelocidades
# 13.490642926693695 nasa/ipac extragalactic
# 12.79749574613375 plano-circulares ajustamos
# 12.79749574613375 ~28 kwh/kg
# 12.104348565573805 ~13 kwh/kg
# 12.104348565573805 cont lat
# 13.490642926693695 preconditioned conjugate
# 12.104348565573805 não-compensada perca
# 12.392030638025586 informantes nazi-fascistas
# 13.490642926693695 veleidades expansionistas
# 12.104348565573805 françois lebrun
# 12.104348565573805 res nulius
# 12.79749574613375 contencioso anglo-francês
# 12.104348565573805 edílson adão
# 12.104348565573805 libras esterlinas
# 12.104348565573805 chefes clânicos
# 12.79749574613375 quadiva ismael
# 13.490642926693695 ismael sentenciou
# 12.104348565573805 adbul hamid
# 12.79749574613375 antoine kitabgi
# 12.104348565573805 muzzafar al-din
# 12.79749574613375 jorro anegrado
# 12.392030638025586 jet noirântre
# 12.392030638025586 noirântre dans
# 12.79749574613375 ciel bleu
# 12.392030638025586 monts zagros
# 12.392030638025586 pétrole dans
# 13.490642926693695 deuxième découverte
# 12.104348565573805 tentava sanear
# 12.104348565573805 entente cordiale
# 13.490642926693695 baghda railway
# 12.79749574613375 ottoman ports
# 13.490642926693695 baghdad rilway
# 12.104348565573805 espionagem germânica
# 13.490642926693695 drang nach
# 13.490642926693695 nach osten10
# 13.490642926693695 turquía incito
# 13.490642926693695 ocupassem bacu
# 12.104348565573805 including diarbekir
# 12.104348565573805 either abdullah
# 12.104348565573805 866 sírios-libaneses
# 12.392030638025586 economical assistance
# 12.79749574613375 provisionally recognized
# 12.79749574613375 administrative advice
# 12.79749574613375 old otoman
# 13.490642926693695 otoman empire
# 12.79749574613375 mush-sairt-ibn umar
# 12.79749574613375 umar amaria
# 13.490642926693695 dargh-jidiz-aaagh-zara-egin hharput
# 12.79749574613375 profeta maomé
# 12.79749574613375 birejik-urfa-midint-jaziret-ibn umar
# 13.490642926693695 comissário macmahon
# 13.490642926693695 achavam encurralados
# 13.490642926693695 margaret macmillan
# 12.79749574613375 surgiam pretensas
# 12.104348565573805 chaim weizmann
# 13.490642926693695 theodor herzl
# 12.79749574613375 arabi pash
# 13.490642926693695 butros bustanim
# 12.79749574613375 negib azury
# 12.104348565573805 azury reclama
# 12.79749574613375 cuyo corazón
# 13.490642926693695 corazón estaría
# 13.490642926693695 malatios khouri
# 13.490642926693695 ian smuts
# 13.490642926693695 pregação wahabita
# 12.392030638025586 grã bretanha
# 12.104348565573805 brigada cossaca
# 12.104348565573805 começado rasgar
# 12.79749574613375 haras al-istqal
# 12.392030638025586 jamil al-midfa
# 12.392030638025586 ahd alinhava
# 13.490642926693695 calouste gulbenkian
# 12.79749574613375 eric hobsbawm
# 13.490642926693695 ma ruf
# 12.79749574613375 muhammad mahdi
# 13.490642926693695 mahdi al-jawahiri
# 13.490642926693695 escreviam poesias
# 12.104348565573805 agradando imensamente
# 13.490642926693695 shu aiba
# 13.490642926693695 hizb al-ikha
# 13.490642926693695 al-ikha al-watani
# 13.490642926693695 ja far
# 13.490642926693695 far abul
# 13.490642926693695 jam iyya
# 13.490642926693695 iyya ashab
# 13.490642926693695 ashab al-san
# 12.79749574613375 mithaq al-sha
# 13.490642926693695 primeiro ministro
# 12.79749574613375 rebeliões ocorressem
# 12.104348565573805 sublevadas comandadas
# 12.104348565573805 hikmat suleiman
# 13.490642926693695 husain fawzi
# 12.104348565573805 salah al-din
# 12.79749574613375 kamil shabib
# 12.79749574613375 aziz yamulki
# 13.490642926693695 nacionais socialistas
# 13.490642926693695 levas migratórias
# 12.104348565573805 benito mussolini
# 13.490642926693695 ismail majzoub
# 12.392030638025586 irgun zvai
# 13.490642926693695 zvai leumi
# 12.79749574613375 revisionistas sionistas
# 13.490642926693695 julgasse depreciativos
# 12.104348565573805 aziz nacib
# 13.490642926693695 nacib ab
# 12.79749574613375 ab saber
# 12.79749574613375 ruth henig
# 12.104348565573805 militarista nipônico
# 12.79749574613375 josef stalin
# 13.490642926693695 freies indien
# 13.490642926693695 russos brancos
# 13.490642926693695 nahas paxá
# 12.104348565573805 al-husseini clamava
# 12.392030638025586 prisioneiros argelinos
# 12.79749574613375 regente recorreu
# 12.104348565573805 ameaçavam abater
# 12.104348565573805 germânica repousava
# 13.490642926693695 landesgruppe brasilien
# 12.392030638025586 aparições grandiosas
# 12.79749574613375 für volksaufklärung
# 12.392030638025586 volksaufklärung und
# 12.79749574613375 gala copiados
# 12.392030638025586 polidamente recusado
# 13.490642926693695 dumbarton oaks
# 13.490642926693695 conceded superiority
# 13.490642926693695 genuine desire
# 12.79749574613375 cartões postais
# 12.104348565573805 península coreana
# 13.490642926693695 batalhão colombiano
# 12.104348565573805 ronald richter
# 12.392030638025586 reprimia violentamente
# 12.392030638025586 gamal abdel
# 12.79749574613375 muhammad naguib
# 12.104348565573805 naguib assumia
# 13.490642926693695 hayif hawatmeh
# 13.490642926693695 haile selassie
# 13.490642926693695 conheceram interregnos
# 13.490642926693695 tse tung
# 12.79749574613375 josep stalin
# 12.104348565573805 catherine kaminsky
# 12.104348565573805 outrora flertaram
# 12.79749574613375 aerotransportadas franco-britânicas
# 12.104348565573805 operação brasil-ásia
# 12.392030638025586 sri lanka
# 12.392030638025586 fitzgerald kennedy
# 13.490642926693695 guinea-west irian
# 13.490642926693695 temporary executive
# 12.79749574613375 executive authority
# 12.104348565573805 assistence programs
# 13.490642926693695 fatherland belongs
# 12.392030638025586 thist vision
# 13.490642926693695 essentially non-marxist
# 12.79749574613375 marines intervieram
# 12.79749574613375 camille chamoun
# 12.79749574613375 fuad chehab
# 12.392030638025586 yitzhak shinchor
# 13.490642926693695 al-hars al-qawmi
# 13.490642926693695 iraquaino mudava
# 12.392030638025586 opunha nasseristas
# 13.490642926693695 di slaibi
# 12.104348565573805 tribo al-jumaila
# 13.490642926693695 guarda pretoriana
# 12.392030638025586 perigo infiel
# 12.79749574613375 retirará momentaneamente
# 12.104348565573805 saído vitoriosa
# 12.79749574613375 882 destinou-se
# 12.392030638025586 aduaneira fracassava
# 12.79749574613375 triênio 1964-1966
# 12.79749574613375 yehoshuah porath
# 12.79749574613375 naji talib
# 13.490642926693695 premier destituindo
# 12.79749574613375 destituindo naji
# 12.104348565573805 ban treaty
# 12.79749574613375 aziz al-hajj
# 12.79749574613375 tahir yahia
# 13.490642926693695 alinhamentos incondicionais
# 12.104348565573805 emílio garrastazu
# 13.490642926693695 hamann rademaker
# 13.490642926693695 rademaker grünewald
# 12.104348565573805 militarização partidária
# 13.490642926693695 sturm abteilung-tropas
# 13.490642926693695 geheime staats
# 13.490642926693695 staats polizei
# 13.490642926693695 hj-juventude hitlerista
# 13.490642926693695 amílcar alencastre
# 12.104348565573805 arturo frondizzi
# 12.104348565573805 arturo illia
# 13.490642926693695 falastini al-tahrir
# 13.490642926693695 al-tahrir al-harkat
# 12.104348565573805 fplp reivindicava
# 13.490642926693695 leila khaled
# 12.79749574613375 abdullah yafi
# 12.392030638025586 abdel razzaq
# 13.490642926693695 razzaq al-yiha
# 12.79749574613375 abu moussa
# 13.490642926693695 nayef hauatmeh
# 13.490642926693695 abd al-wahhab
# 13.490642926693695 al-wahhab al-kayyalli
# 12.79749574613375 abu nidal
# 12.79749574613375 khidir hamza
# 12.79749574613375 moyesser al-mallah
# 12.104348565573805 husham sharif
# 12.79749574613375 ai-5 silenciou
# 12.392030638025586 esteticamente feio
# 12.79749574613375 nizar messari
# 13.490642926693695 anwar saddat
# 13.490642926693695 saddat expulsara
# 13.490642926693695 leopold senghor
# 12.79749574613375 alterava irrevogavelmente
# 13.490642926693695 sofressem vertiginosos
# 13.490642926693695 hisham al-shawi
# 13.490642926693695 suroor mahmoud
# 13.490642926693695 mahmoud mirza
# 12.79749574613375 khalid ibrahim
# 12.79749574613375 ibrahim saeed
# 13.490642926693695 secto semita
# 12.392030638025586 solicitarem mediadores
# 12.392030638025586 christian lohbauer
# 12.79749574613375 sentiu-se agredido
# 13.490642926693695 caças mirage
# 12.79749574613375 barter trader
# 13.490642926693695 which ordered
# 12.79749574613375 armored vehicles
# 12.104348565573805 arms supplier
# 12.79749574613375 armed forces
# 12.104348565573805 open sub-saharian
# 13.490642926693695 spiegel falava
# 13.490642926693695 mdb aplaudia
# 12.392030638025586 trocaram embaixadores
# 13.490642926693695 anuar sadat
# 13.490642926693695 constructions navales
# 13.490642926693695 anastácio somoza
# 12.104348565573805 ex-ditador nicaragüense
# 12.104348565573805 nicaragüense partia
# 13.490642926693695 babrak karmal
# 12.104348565573805 retomaram herat
# 12.104348565573805 patãs usavam
# 12.79749574613375 baquir al-sadr
# 12.104348565573805 om qasr
# 12.392030638025586 divulgando ultimatos
# 12.79749574613375 área conflagrada
# 12.104348565573805 bombardeava incessantemente
# 12.392030638025586 clero fundamentalista
# 12.79749574613375 bani sadr
# 12.79749574613375 fundamentalistas venceram
# 12.392030638025586 iraque ateu
# 12.392030638025586 hemispheric affairs
# 13.490642926693695 cubanos anticastristas
# 12.104348565573805 fred halliday
# 12.392030638025586 salman pak
# 12.104348565573805 pró-iraque unia
# 12.392030638025586 elegeu tancredo
# 12.392030638025586 argentino-brasileira atravessava
# 13.490642926693695 tenente-brigadeiro sócrates
# 12.392030638025586 xinjiang uyghur
# 12.79749574613375 uyghur autonomous
# 13.490642926693695 foguete al-abid
# 13.490642926693695 sudanês combatesse
# 12.79749574613375 emb-312 tucano
# 13.490642926693695 analúcia danilevicz
# 12.392030638025586 reservistas convocavam
# 12.104348565573805 greatest military
# 12.104348565573805 military deployment
# 12.79749574613375 logistical effort
# 12.392030638025586 massey fergusson
# 12.79749574613375 tarso flecha
# 12.392030638025586 diplomata empenhado
# 13.490642926693695 desert storm
# 13.490642926693695 razões patrióticas
# 12.104348565573805 brasil collorido
# 12.104348565573805 colecionar fracassos
# 12.392030638025586 tornassem eternos
# 13.490642926693695 deslumbramento provinciano
# 12.104348565573805 saul menem
# 12.79749574613375 bilateralismo washington-brasília
# 13.490642926693695 mero coadjuvante
# 13.490642926693695 cosme degenor
# 12.392030638025586 degenor drumond
# 13.490642926693695 aron preconizou
# 12.79749574613375 misericórdia collorido
# 13.490642926693695 jalal jamel
# 13.490642926693695 inseguro/condição insegura
# 12.392030638025586 coloquialmente confundido
# 12.79749574613375 despacha vagões-tanque
# 13.490642926693695 adiministration/task load
# 12.104348565573805 violações deliberadas
# 12.79749574613375 oskar morgenstern
# 12.104348565573805 comercializadora infoenergy
# 12.79749574613375 objetava veementemente
# 13.490642926693695 nouvelle ruée
# 13.490642926693695 ruée vers
# 13.490642926693695 monopolios estatales
# 12.104348565573805 angolana sonagol
# 12.392030638025586 muamar kadafi
# 12.79749574613375 partilharam secretamente
# 13.490642926693695 türkýye petrollerý
# 13.490642926693695 petrollerý anoným
# 13.490642926693695 anoným ortaklidi
# 13.490642926693695 boqueron profunfo
# 13.490642926693695 pichu picún
# 13.490642926693695 picún leufu
# 12.79749574613375 gualberto villaroel
# 12.79749574613375 guillermo elder
# 12.79749574613375 côo bndes/finame
# 12.392030638025586 havia-se incrustado
# 13.490642926693695 agro-industriais intra-bloco
# 12.104348565573805 lampreia usava
# 12.392030638025586 guarajá mirim
# 13.490642926693695 consultoras booz
# 12.104348565573805 custo sul-américa
# 13.490642926693695 vélez sarsfield
# 12.79749574613375 comodoro rivadavia
# 12.104348565573805 saúl menem
# 13.490642926693695 lãs mercedes
# 12.79749574613375 compañia inversora
# 13.490642926693695 rúa clamou
# 12.79749574613375 ramón puerta
# 12.104348565573805 outorgava faculdades
# 12.79749574613375 galinha poedeira
# 12.392030638025586 gros minimizava
# 12.104348565573805 demandassem sofisticado
# 12.104348565573805 promoviam nacionalizações
# 12.392030638025586 patino mines
# 12.104348565573805 mauricio hochschild
# 12.392030638025586 mergarejo concede
# 13.490642926693695 agustin iturricha
# 13.490642926693695 dueto mnr-cob
# 12.79749574613375 melhorava francamente
# 12.104348565573805 utopia desarmada
# 13.490642926693695 sica sica-ararica
# 12.104348565573805 companheiro holland
# 13.490642926693695 robore agreements
# 12.392030638025586 ovando candia
# 12.79749574613375 foi-lhes vetado
# 12.104348565573805 intrépidos parlamentares
# 13.490642926693695 envolvimentos ilícitos
# 12.79749574613375 sentiu-se constrangido
# 12.392030638025586 siles zuazo
# 12.392030638025586 zuazo descortinava
# 12.104348565573805 pagando-lhes indenizações
# 13.490642926693695 sezione speciale
# 13.490642926693695 acuerdos comerciales
# 12.392030638025586 tenha-se tornada
# 12.79749574613375 iso/tr 11046
# 12.104348565573805 100 200
# 13.490642926693695 zech umwelt
# 12.104348565573805 umweltschutz nord
# 13.490642926693695 cuestas basálticas
# 12.79749574613375 basculante enlonados
# 13.490642926693695 minirae 2000-portable
# 13.490642926693695 hrgc fid
# 12.104348565573805 trituração homogenização
# 13.490642926693695 iso/dis 16703
# 13.490642926693695 2525* 5000*
# 12.392030638025586 hombres europeos
# 13.490642926693695 europeos canónicos
# 13.490642926693695 mikhail mikhailovich
# 13.490642926693695 mikhailovich bakhtin
# 12.104348565573805 moça obediente
# 12.104348565573805 ¿lo oculta
# 13.490642926693695 entidad autónoma
# 12.79749574613375 cómo reaccionar
# 13.490642926693695 contenidos semánticos
# 12.79749574613375 personalidades femeninas
# 12.104348565573805 escudo matrimonial
# 13.490642926693695 esas informaciones
# 13.490642926693695 masa oscura
# 13.490642926693695 estudiante universitaria
# 12.79749574613375 universitaria clase
# 12.79749574613375 patraña elemental
# 12.392030638025586 contraer matrimonio
# 13.490642926693695 usé anticonceptivos
# 13.490642926693695 dejándome atravesar
# 12.392030638025586 condición disminuye
# 12.79749574613375 debo prepararme
# 13.490642926693695 aprenda yudo
# 12.104348565573805 mismo ¿verdad
# 12.79749574613375 carabobo tendría
# ...
# 12.392030638025586 triethylene glycol
# 12.392030638025586 glycol monobutyl
# 12.104348565573805 caneta esferográfica
# 12.392030638025586 canetas esferográficas
# 12.79749574613375 attomole amounts
# 12.392030638025586 packed columns
# 13.490642926693695 illicit drugs
# 12.392030638025586 irish euro
# 12.104348565573805 toner printed
# 12.104348565573805 pigmented inkjet
# 12.104348565573805 inkjet printer
# 13.490642926693695 printer inks
# 12.79749574613375 deutsche gold-und
# 13.490642926693695 gold-und silber-scheideanstalt
# 13.490642926693695 silber-scheideanstalt vormals
# 13.490642926693695 vormals roessler
# 12.392030638025586 de2648539c2 fuji
# 12.104348565573805 inkjet recording
# 12.79749574613375 includes surfynol
# 12.104348565573805 surfynol surfactant
# 12.104348565573805 waterbased medium
# 12.104348565573805 minimal destructive
# 12.392030638025586 bleached 1-
# 13.490642926693695 solid-phase microextraction
# 12.79749574613375 australian polymeric
# 12.104348565573805 lachrymator residues
# 12.392030638025586 tetraethylene glycol
# 12.392030638025586 glycol monoethylhexyl
# 13.490642926693695 ethoxylated oligomers
# 13.490642926693695 282 291
# 13.490642926693695 1169 1172
# 12.79749574613375 counterfeited banknote
# 12.79749574613375 banknote pigments
# 12.104348565573805 document examiners
# 13.490642926693695 220 225
# 13.490642926693695 positive-ion chemical-ionization
# 12.104348565573805 questioned document
# 12.79749574613375 solvent-free gold
# 12.79749574613375 gold nanoparticle-assisted
# 12.392030638025586 fake euro
# 13.490642926693695 silanizante heptadecafluoro-1
# 13.490642926693695 nicolet 6700
# 12.392030638025586 microporoso funcionalizado
# 12.392030638025586 polimetil metacrilato
# 13.490642926693695 doubly resonant
# 13.490642926693695 interferometric biosensor
# 12.104348565573805 thin films
# 12.392030638025586 maldi-ms substrates
# 13.490642926693695 european bioplastics
# 13.490642926693695 sutura cirúrgica
# 13.490642926693695 p212121 d4
# 12.79749574613375 cð1ð2ð ðr
# 12.79749574613375 chcl/dmf 2/8
# 12.392030638025586 100kg cm-2
# 12.104348565573805 eclipse 80i
# 13.490642926693695 sight ds-fi1
# 13.490642926693695 linkam css
# 12.79749574613375 jsm 6340f
# 12.392030638025586 metalizador bal-tec
# 13.490642926693695 differencial refractometer
# 12.104348565573805 precipitação/ termomoldagem
# 12.79749574613375 tank owner
# 12.79749574613375 tanker owners
# 12.104348565573805 2001e pesarini
# 13.490642926693695 nima 302ll
# 13.490642926693695 whatmans´s chrl
# 13.490642926693695 elisabete zaniquelli
# 12.392030638025586 s5200 hitachi
# 12.104348565573805 980 cm/s2
# 12.392030638025586 emitting diode
# 13.490642926693695 máx= 580nm
# 12.104348565573805 benjamin franklin
# 12.79749574613375 steel catenary
# 12.392030638025586 norman gall
# 13.490642926693695 runge kutta
# 12.392030638025586 ò8 s
# 12.392030638025586 s òt8
# 12.392030638025586 notações qø
#  ï
# 13.490642926693695 ï í
# 12.79749574613375 ù× v4
# 12.392030638025586 e=0 =
# 13.490642926693695 generalisada 74
# 13.490642926693695 764 =84
# 12.392030638025586 î=106 0/i7
# 12.392030638025586 î=107 0/i7
# 13.490642926693695 î= 108
# 12.392030638025586 108 0/i7
# 13.490642926693695 flip bifurcation
# 12.392030638025586 ëø ìøìø
# 12.392030638025586 ìøìø íø
# 12.392030638025586 íø öø
# 12.104348565573805 öø ÷ø÷ø
# 12.104348565573805 ÷ø÷ø øø
# 13.490642926693695 64 +65
# 12.79749574613375 implantes ósseos
# 13.490642926693695 walther gerlach
# 13.490642926693695 pesam toledas
# 13.490642926693695 gea vidoto
# 13.490642926693695 aparecido donizeti
# 12.104348565573805 bobinas solenoidais
# 12.104348565573805 console discovery
# 12.79749574613375 roberta delcolle
# 13.490642926693695 claudia cristiane
# 13.490642926693695 cristiane camilo
# 13.490642926693695 pvb/ butvar
# 13.490642926693695 butvar b98
# 12.79749574613375 pactos interestaduais
# 12.79749574613375 tenesse authority
# 12.104348565573805 authority valley
# 13.490642926693695 sardar sarovar
# 13.490642926693695 parambikulam aliyar
# 12.392030638025586 interactive river-aquifer
# 12.104348565573805 army corps
# 12.79749574613375 plateau tibetano
# 12.79749574613375 smin oper
# 12.392030638025586 embu guaçu
# 12.392030638025586 bela vista/conceição
# 13.490642926693695 ermelino matarazzo
# 12.104348565573805 eeab guaratuba
# 12.392030638025586 descartou sobretaxa
# 13.490642926693695 tj-sp derrubou
# 12.79749574613375 ana-daee nº335
# 12.104348565573805 aproveitamentos hidroelétricos
# 12.104348565573805 métricos separáveis
# 12.79749574613375 semicontínua inferiormente
# 12.104348565573805 semicontínua superiormente
# 12.79749574613375 µ-coberturas µ
# 12.104348565573805 brownianos ordinários
# 13.490642926693695 jaques curie
# 12.104348565573805 gabriel lipmann
# 12.79749574613375 titanato zirconato
# 13.490642926693695 mototaro eguchi
# 12.79749574613375 bayonet neil
# 12.79749574613375 neil concelman
# 13.490642926693695 etileno-propileno fluorado
# 13.490642926693695 1/25ø ß5øeü25ø6ü
# 13.490642926693695 tektronik afg
# 13.490642926693695 afg 3022c
# 12.392030638025586 keysight mso7104b
# 12.392030638025586 keysight dsox2002a
# 13.490642926693695 low-cost electro-acoustic
# 13.490642926693695 ferroelectret transducer
# 12.79749574613375 electrical insulation
# 12.392030638025586 dielectric phenomena
# 12.104348565573805 visivelmente contrariada
# 12.104348565573805 emergiu originariamente
# 12.79749574613375 estruturalistas reverberaram
# 12.79749574613375 enzo faletto
# 12.392030638025586 larry diamond
# 13.490642926693695 agonistic pluralism
# 12.392030638025586 amartya sen
# 12.104348565573805 cass sunstein
# 13.490642926693695 facury scaff
# 13.490642926693695 lênio streck
# 12.392030638025586 exploratory essay
# 12.104348565573805 johns hopkins
# 12.392030638025586 peasants reacted
# 13.490642926693695 prosperous bourgeoisie
# 13.490642926693695 getting rid
# 12.79749574613375 longer gave
# 12.392030638025586 ancient privileges
# 12.104348565573805 take away
# 12.104348565573805 fraternity meant
# 12.392030638025586 deliberadamente rechaça
# 12.392030638025586 renomado pupilo
# 13.490642926693695 huntington's legacy
# 12.79749574613375 otherwise --
# 13.490642926693695 encenação teatral
# 13.490642926693695 becomes democratic
# 13.490642926693695 credible threat
# 12.104348565573805 military coups
# 12.104348565573805 coups designed
# 13.490642926693695 modernization continued
# 12.104348565573805 became increasingly
# 12.79749574613375 increasingly confident
# 12.104348565573805 violate mandates
# 12.104348565573805 violated mandates
# 13.490642926693695 held accountable
# 12.79749574613375 switches tell
# 12.392030638025586 marc leroy
# 12.104348565573805 staatssozialismus oder
# 12.104348565573805 oder staatskapitalismus
# 12.104348565573805 especializações disciplinares
# 12.392030638025586 compreensiva manifestava-se
# 13.490642926693695 rational bureaucratization
# 12.392030638025586 bureaucratization studied
# 12.392030638025586 ajay mehrotra
# 12.104348565573805 monica prasad
# 12.79749574613375 agissem corruptamente
# 12.79749574613375 large-scale bureaucracy
# 13.490642926693695 bureaucracy soon
# 13.490642926693695 soon runs
# 12.79749574613375 pay salaries
# 12.104348565573805 make officials
# 12.392030638025586 officials dependent
# 12.79749574613375 carolyn webber
# 12.79749574613375 aaron wildavsky
# 12.104348565573805 artifício elitista
# 13.490642926693695 toke aidt
# 12.104348565573805 voting franchise
# 13.490642926693695 soziale marktwirtschaft
# 12.104348565573805 trabalhadoras desloquem
# 12.104348565573805 allan meltzer
# 12.392030638025586 andrew warner
# 12.392030638025586 andrew rosser
# 12.104348565573805 rent dependency
# 13.490642926693695 leonard wantchekon
# 12.79749574613375 coming scramble
# 13.490642926693695 ilham aliyev
# 12.79749574613375 pretensa assepsia
# 12.79749574613375 harold hotelling
# 12.79749574613375 durable exhaustible
# 13.490642926693695 antonia juhasz
# 13.490642926693695 elizabeth granitz
# 13.490642926693695 raising rival´s
# 12.392030638025586 rival´s costs
# 12.104348565573805 epic quest
# 12.392030638025586 aguila companía
# 13.490642926693695 latifundiário basco
# 12.392030638025586 pareçam insinuar
# 12.104348565573805 arnaldo cordova
# 12.79749574613375 redistributive constraints
# 12.392030638025586 laws instead
# 12.79749574613375 accept legislation
# 13.490642926693695 never wanted
# 12.392030638025586 they did
# 13.490642926693695 commit suicide
# 12.104348565573805 year old
# 12.79749574613375 satisfy every
# 13.490642926693695 ordenações ibéricas
# 12.79749574613375 contestou vitoriosamente
# 12.392030638025586 come here
# 12.79749574613375 pick him
# 13.490642926693695 even though
# 13.490642926693695 supreme court
# 12.79749574613375 private persons
# 13.490642926693695 concession seekers
# 12.79749574613375 seekers now
# 12.79749574613375 subtle influences
# 13.490642926693695 complaisant partner
# 13.490642926693695 veicularam obituários
# 13.490642926693695 obituários elogiosos
# 12.79749574613375 serious effort
# 12.79749574613375 immensely difficult
# 12.392030638025586 proletariat made
# 12.104348565573805 trygve lie
# 13.490642926693695 einar gerhardsen
# 12.392030638025586 cannot recommend
# 12.79749574613375 engage itself
# 12.104348565573805 inevitably become
# 12.79749574613375 tanker fleet
# 12.104348565573805 floresceu tardiamente
# 13.490642926693695 leon m
# 13.490642926693695 m bá
# 12.104348565573805 omar bongo
# 12.392030638025586 nico schrijver
# 12.104348565573805 repetidamente acentuaram
# 12.79749574613375 nacionalizações unilaterais
# 12.392030638025586 requisitioning shall
# 13.490642926693695 overriding purely
# 12.79749574613375 peoples freely
# 12.104348565573805 mannaraswamighala rajan
# 12.79749574613375 perdedor sofreriam
# 13.490642926693695 advises everybody
# 13.490642926693695 valid excuse
# 12.104348565573805 his family
# 12.104348565573805 starving men
# 12.392030638025586 taking place
# 12.79749574613375 equivocadamente superestimada
# 12.392030638025586 few precedents
# 13.490642926693695 jubilant demonstrations
# 12.79749574613375 partly organized
# 12.104348565573805 great massive
# 12.79749574613375 massive display
# 12.79749574613375 eric magar
# 12.104348565573805 neither populism
# 12.79749574613375 ognen stojanovski
# 13.490642926693695 evaluación anticipada
# 12.104348565573805 ousavam advogar
# 12.392030638025586 raúl leoni
# 12.104348565573805 preferiu ater-se
# 12.392030638025586 edwin lieuwin
# 12.104348565573805 imprevista avalanche
# 13.490642926693695 authoritative allocation
# 12.392030638025586 continuassem lucrando
# 13.490642926693695 newsi d_temas=13
# 12.104348565573805 crudo extrapesado
# 12.79749574613375 citgo consolidando-se
# 12.392030638025586 misión barrio
# 12.392030638025586 stats oljeselskep
# 12.79749574613375 trygve bratteli
# 12.392030638025586 dez mandamentos
# 12.104348565573805 aumentassem indesejavelmente
# 12.79749574613375 saga petrolleum
# 12.104348565573805 tripartite divisada
# 13.490642926693695 kare willoch
# 13.490642926693695 vidkunn hveding
# 12.104348565573805 recomendou aguardar-se
# 12.104348565573805 evolving champion
# 13.490642926693695 harald norvik
# 13.490642926693695 arve johnsen
# 12.79749574613375 abusos perpetrados
# 13.490642926693695 hesita trair
# 12.79749574613375 presidential succession
# 13.490642926693695 new populism
# 13.490642926693695 populism arose
# 13.490642926693695 nationalist businessmen
# 12.392030638025586 traditional agrarian
# 12.104348565573805 occasional papers
# 13.490642926693695 extravagância creditícia
# 13.490642926693695 silvana tordo
# 13.490642926693695 ola listhaug
# 12.104348565573805 324 bent
# 13.490642926693695 bent sofus
# 13.490642926693695 sofus tranoy
# 12.79749574613375 acabassem sabotando
# 13.490642926693695 vice-ministro ivan
# 13.490642926693695 ivan pulido
# 13.490642926693695 pulido mora
# 13.490642926693695 reinventing legitimacy
# 12.79749574613375 359 matthew
# 12.104348565573805 plebiscito revocatório
# 13.490642926693695 reparto ejecutivo
# 13.490642926693695 épico editorial
# 12.392030638025586 úslar pietri
# 12.104348565573805 prestigiado criador
# 12.104348565573805 estadísticas oportunas
# 13.490642926693695 mx/politicafinanciera/finanzaspublicas/estadisticas_oportunas_finanzas_pu blicas/informacion_mensual/paginas/finanzas_publicas
# 12.392030638025586 estabelecem-se quotas
# 12.79749574613375 experimentava baixíssimos
# 12.104348565573805 rené villarreal
# 12.79749574613375 longer-term viability
# 12.392030638025586 nora lustig
# 12.392030638025586 assistance packages
# 12.392030638025586 acrônimo pidiregas
# 12.79749574613375 insuficientemente regulamentado
# 12.79749574613375 hernández saldaña
# 12.79749574613375 rubens penha
# 12.79749574613375 penha cysne
# 12.79749574613375 rogério sobreira
# 12.392030638025586 418 rocio
# 12.104348565573805 rocio moreno
# 13.490642926693695 responsabilidad hacendaria
# 12.79749574613375 oysten noreng
# 12.392030638025586 barry poulson
# 12.104348565573805 jens stoltenberg
# 12.79749574613375 434 olav
# 13.490642926693695 olav bjertkholt
# 13.490642926693695 lorents lorentsen
# 13.490642926693695 steinar strom
# 12.104348565573805 infrastructure investment
# 12.392030638025586 bard college
# 12.79749574613375 knut halvorsen
# 12.79749574613375 steiner stjerno
# 13.490642926693695 newly industrializing
# 13.490642926693695 norio usui
# 12.392030638025586 andrew feltenstein
# 12.104348565573805 441 stephany
# 13.490642926693695 stephany griffith-jones
# 13.490642926693695 frederic samama
# 12.79749574613375 economist cunhar
# 13.490642926693695 rent seeking
# 12.104348565573805 454 452
# 12.392030638025586 ragnar torvik
# 12.392030638025586 stephen macserraigh
# 12.79749574613375 tracking vulnerabilities
# 13.490642926693695 sanjay pradhan
# 13.490642926693695 anne krueger
# 12.392030638025586 transparency initiatives
# 13.490642926693695 andreanna truelove
# 13.490642926693695 ivar kolstad
# 13.490642926693695 arne wiig
# 12.104348565573805 roby rajan
# 13.490642926693695 desempregados educados
# 12.79749574613375 veem-se incentivados
# 12.79749574613375 misiones programs
# 12.79749574613375 electoral participation
# 12.79749574613375 erika weinthal
# 12.104348565573805 pandiá calógeras
# 12.104348565573805 lei calógeras
# 13.490642926693695 matéria prima
# 12.79749574613375 percival farquhar
# 12.392030638025586 iron ore
# 12.104348565573805 caetano horta
# 12.392030638025586 romancista acusou
# 13.490642926693695 logrado constitucionalizar
# 12.104348565573805 comprometer-se publicamente
# 12.104348565573805 maurício tiomno
# 12.79749574613375 tiomno tolmasquim
# 13.490642926693695 br/sitebndes/export/sites/default/bndes_pt/galerias/arquivos/produtos/ download/chamada_publica_fepprosp0111_apresresultado
# 12.392030638025586 pós-sal limitavam
# 12.392030638025586 523 argumentando-se
# 13.490642926693695 dádivas irrefutáveis
# 12.392030638025586 precise imiscuir-se
# 13.490642926693695 chamarão impropriamente
# 12.392030638025586 emenda ibsen
# 12.104348565573805 piauiense wellington
# 12.392030638025586 subterfúgios interpretativos
# 13.490642926693695 pônsio pilatos
# 12.79749574613375 revenue assignments
# 13.490642926693695 giorgio brosio
# 13.490642926693695 cazeiro lopreato
# 12.79749574613375 lumen juris
# 12.104348565573805 585 veja-se
# 13.490642926693695 478/97 repartia
# 13.490642926693695 dj 16-11-2001
# 12.79749574613375 belos calçamentos
# 12.79749574613375 andreas engen
# 13.490642926693695 oluf laghelle
# 13.490642926693695 reidar bratvold
# 13.490642926693695 brenda schaffer
# 13.490642926693695 taleh ziyadov
# 12.104348565573805 fortaleça institucionalmente
# 12.79749574613375 how archaeologists
# 13.490642926693695 archaeologists discovered
# 12.79749574613375 international maritime
# 12.104348565573805 +/- 80m
# 12.392030638025586 sealy gosset
# 13.490642926693695 cervejaria guinness
# 12.104348565573805 malthus escreveu
# 12.79749574613375 extremados contra-argumentavam
# 13.490642926693695 18q 28q
# 13.490642926693695 zlm zmm
# 12.79749574613375 -96 -21
# 13.490642926693695 -17 -35
# 12.79749574613375 -35 -33
# 12.79749574613375 -33 -479
# 13.490642926693695 -479 -124
# 13.490642926693695 remediações afetarão
# 12.392030638025586 feto dermico
# 13.490642926693695 protozoário ciliado
# 12.104348565573805 alfonic 810-60
# 12.104348565573805 polychloride biphenyl
# 12.79749574613375 sapogenat t-300
# 13.490642926693695 akopal n-300
# 13.490642926693695 obserevações degração
# 12.392030638025586 liner descartável
# 13.490642926693695 ss-03 ss-04
# 13.490642926693695 ss-04 ss-05
# 13.490642926693695 ss-01/4 ss-03/1
# 13.490642926693695 ss-03/1 ss-04/2
# 13.490642926693695 ss-04/2 ss-05/3

# %%
# Função que recebe um sentença e o dicionário com MWE e retorna a sentença com os MWE unidos por "_". 

def uni_MWE(sent, mwe):
    
    mwe_tokenizer = MWETokenizer(list(mwe.keys()))
    sent = nltk.word_tokenize(sent)
    sent = mwe_tokenizer.tokenize(sent)
    sent = TreebankWordDetokenizer().detokenize(sent)
    return (sent)

# %% [markdown]
# Para cada arquivos do diretórios especificado lemos e preprocessamos o texto, unimos os bigrams considerados MWE, criamos uma rede de markov com os n-grams (state_size) e combinamos os modelos de todos os arquivos.

# %%
# Contador de tempo
start_time = time.time()

# Cadeia de Markov combinada
combined_model = None

# Contagem de arquivos
n_files = 0

# Iterar pelos diretórios e arquivos
for (dirpath, _, filenames) in os.walk("Originais/treino"):
    for filename in filenames:
        n_files += 1
        
        try:
            # Ler o arquivo e criar uma cadeia de Markov para cada arquivo
            with open(os.path.join(dirpath, filename), 'rb') as f:
                
                # Preprocessar o texto lido
                text = preprocess(f.read())
                text_mwe = []
                
                # Unir as MWE
                for sent in text:
                    text_mwe.append(uni_MWE(sent, mwe))
                
                # Treinar o modelos usando as o texto preprocessado e com MWE
                model = markovify.NewlineText(text_mwe, retain_original=False, state_size=2)

                # Combinar modelo criado para um arquivo com a Cadeia de Markov combinada
                if combined_model:
                    combined_model = markovify.combine(models=[combined_model, model])
                else:
                    combined_model = model
        except:
            print("Não foi possível ler o arquivo", filename)
            #pass
                    
        # Contador de arquivos processados
        if n_files % 50 == 0:
            print ("--- %s arquivos processados ---" % n_files, "--- %s seconds ---" % (time.time() - start_time))
    
# Fim do contador de tempo
print ("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 50 arquivos processados --- --- 537.3928475379944 seconds ---
# --- 100 arquivos processados --- --- 1143.8330619335175 seconds ---
# --- 1596.6718480587006 seconds ---

# %%
# Imprimir um exemplo de sentença aleatória
print(combined_model.make_sentence(max_words=50))
# Out:
# 11,  respectivamente

# %%
# Gravar modelo em JSON em disco
#model_json = combined_model.to_json()
#with open('MarkovChainModel_mwe_MI12.json', 'w') as f:
#    json.dump(model_json, f)

# %%
# Carregar modelo em JSON do disco
#with open('MarkovChainModel_mwe_MI12.json', 'r') as f:
#    model_json = markovify.Text.from_json(json.load(f))

# %% [markdown]
# Como os textos usados são em português, foi necessário codificar em 'ISO 8859-1', já o modelo JSON está codificado em UTF16. Portanto, ao ler e consultar os termos do modelo é necessário usar a codificação correta.

# %%
# Geração de sentença aleatória que iniciam com n-palavras

# Palavras que serãao usadas como semente
palavra_1 = 'a'
palavra_2 = 'petrobras'

# Ajustando a codificação para ser usado no modelo
palavra_1 = ' ' + palavra_1 + ' '
palavra_2 = ' ' + palavra_2
palavra_1 = palavra_1.encode('utf16')[3:]
palavra_2 = palavra_2.encode('utf16')[4:]
seed = palavra_1 + palavra_2

#Criando sentença aleatória iniciando com as palavras sementes
print(combined_model.make_sentence_with_start(seed.decode()))
# Out:
# a petrobras também,  que realiza o mesmo perfil de distribuição física a camada física

# %% [markdown]
# Do modelo criado pela biblioteca Markovify, extraímos a cadeia de Markov e gravamos em um dicionário

# %%
# Extrair cadeia de Markov do modelo
chain = combined_model.to_dict()['chain']
# Transformando a cadeia em um dicionário 
dic = {}
for state in json.loads(chain):
    dic[(state[0][0],state[0][1])] = state[1]

# %% [markdown]
# Criamos uma função para consultar a cadeia de Markov. Dado duas palavras, extraímos as próximas palavras possíveis, a contagem delas no conjunto de treinamento e a soma total. Dessa forma conseguimos calcular  $p(x_3|x_2,x_1)$.

# %%
# Função que dado duas palavras, retorna um dicionários com as probabilidades das palavras seguintes
def query_chain(palavra_1, palavra_2):
    # Selecionar o dicionário cuja entrada é o par de palavras "palavra_1" e "palavra_2"
    d = dic[(palavra_1, palavra_2)]
    new_d = {}
    # Transformar a contagem de palavras em probabilidade
    for w in d:
        new_d[w] = d[w]/sum(d.values())
    return (new_d)

# %% [markdown]
# O calculamos a perplexidade para cada sentença. Dada as primeiras palavras, obtivemos do modelo a probabilidade da palavra seguinte. Em seguida, avançamos pela sentença recuperando as probablidades.

# %%
# Dada uma sentença, a função retorna uma lista com as entropias calculada para cada trio de palavras
def entropy(sent):
    # Primeiro unimos os MWE
    sent = uni_MWE(sent, mwe)
    # Quebra a sentença em tokens
    words = nltk.word_tokenize(sent)
    # Variável para guardar a entropia de cada conjunto de palavras
    ln_prob_Xi = []
    # Janela de iteração pela sentença
    for w in range(len(words)-2):
        # Cálculo a entropia
        try:
            ln_prob_Xi.append(- math.log(query_chain(words[w], words[w+1])[words[w+2]]))
        except:
            pass

    return(np.mean(ln_prob_Xi))

# %%
# Função que recebe uma string com o caminho e nome da pasta com os arquivos e retorna a perplexidade

def perplexity(dirpath):

    # Início do contador de tempo
    start_time = time.time()
    
    # Variável para armazenar as entropias
    ent = []

    # Contagem de arquivos
    n_files = 0
    # Iterando pelos arquivos da pasta indicada em
    for (dirpath, _, filenames) in os.walk(dirpath):
        
        for filename in filenames:
            n_files += 1
            try:
                # Ler o arquivo e calcular a entropia
                with open(os.path.join(dirpath, filename), 'rb') as f:
                    # Preprocessar o texto lido
                    text = preprocess(f.read())
                    #Calcular a entropia da sentença
                    for sent in text:
                        ent.append(entropy(sent))

            except:
                print("Não foi possível ler o arquivo", filename)
        
                
            # Contador de arquivos processados
            if n_files % 5 == 0:
                print ("--- %s arquivos processados ---" % n_files, "--- %s seconds ---" % (time.time() - start_time))
    
    
    # Transformando a lista de entropias em uma np.array e excluir os valores "nan"
    ent = np.array(ent)
    ent = ent[~np.isnan(ent)]
    
    # Fim do contador de tempo
    print ("--- %s seconds ---" % (time.time() - start_time))
    
    return (math.exp(np.mean(ent)))

# %%
perplexity("Originais/teste")
# Out:
# C:\Users\upe2\AppData\Roaming\Python\Python36\site-packages\numpy\core\fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\upe2\AppData\Roaming\Python\Python36\site-packages\numpy\core\_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# --- 5 arquivos processados --- --- 124.25819945335388 seconds ---
# --- 10 arquivos processados --- --- 253.72885298728943 seconds ---
# --- 354.6159131526947 seconds ---
# 17.966253778929183
